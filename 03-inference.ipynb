# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.tabular.all import *
from wwf.tab.export import *
from bnb import *

from classes import *
from utils import *

# %%
SEASON = '21'

# %% [markdown]
# ## Download HKJC odds

# %%
path_raw = Path('raw_data')
path_data = Path('data')

path_output = Path('output')

# %%
session = requests.Session()
r = session.get('http://bet.hkjc.com')
cookies = r.cookies

# %%
odds_url = 'https://bet.hkjc.com/football/getJSON.aspx?jsontype=odds_chl.aspx'
response = session.post(
    odds_url,
    headers={'referer':'http://bet.hkjc.com'},
    cookies=cookies
)

# %%
with open(path_data/'json'/f'odds_chl-{datetime.now().strftime("%Y-%m-%d-%H-%M-%S")}.txt', 'w') as f:
    f.write(response.text)

# %%
matches_json = json.loads(response.text)[1]['matches']

# %%
# Example
# matches_json = json.loads(open(path_data/'json'/'odds_chl-2021-09-21-14-03-17.txt').read())[1]['matches']

# %%
matches = [Match(m) for m in matches_json]
odds = [m.export() for m in matches]
# Out:
# ['20211029FRI1', '2021-Oct-30', '00:00:00', 'Russian Premier [RPL]', 'Zenit St. Petersburg', 'Dinamo Moscow', 'false', '13.5', '4.15', '1.18', 'false', '11.5', '2.65', '1.42', 'true', '10.5', '2.05', '1.68']
# ['20211029FRI2', '2021-Oct-30', '00:30:00', 'German Division 2 [GD2]', 'Heidenheim', 'Schalke 04', 'false', '11.5', '2.45', '1.48', 'true', '10.5', '2.00', '1.72', 'false', '14.5', '5.55', '1.10']
# ['20211029FRI3', '2021-Oct-30', '00:30:00', 'German Division 2 [GD2]', 'Darmstadt', 'Nurnberg', 'false', '10.5', '2.20', '1.59', 'false', '13.5', '4.90', '1.13', 'true', '9.5', '1.75', '1.95']
# ['20211029FRI9', '2021-Oct-30', '02:30:00', 'German Division 1 [GSL]', 'Hoffenheim', 'Hertha Berlin', 'true', '9.5', '1.80', '1.90', 'false', '10.5', '2.25', '1.57', 'false', '13.5', '4.90', '1.13']
# ['20211029FRI12', '2021-Oct-30', '02:45:00', 'Eng Championship [ED1]', 'QPR', 'Nottingham Forest', 'true', '10.5', '2.05', '1.68', 'false', '11.5', '2.65', '1.42', 'false', '13.5', '4.30', '1.17']
# ['20211029FRI13', '2021-Oct-30', '03:00:00', 'French Division 1 [FFL]', 'Paris Saint Germain', 'Lille', 'true', '9.5', '1.77', '1.93', 'false', '10.5', '2.20', '1.59', 'false', '13.5', '4.90', '1.13']
# ['20211030SAT1', '2021-Oct-30', '12:00:00', 'Japanese Division 2 [JD2]', 'Blaublitz Akita', 'Zweigen Kanazawa', 'false', '13.5', '4.90', '1.13', 'true', '9.5', '1.83', '1.87', 'false', '10.5', '2.30', '1.54']
# ['20211030SAT2', '2021-Oct-30', '12:05:00', 'Japanese League Cup [JLC]', 'Nagoya Grampus', 'Cerezo Osaka', 'true', '8.5', '1.75', '1.95', 'false', '9.5', '2.25', '1.57', 'false', '12.5', '4.90', '1.13']
# ['20211030SAT3', '2021-Oct-30', '13:00:00', 'Japanese Division 2 [JD2]', 'Omiya Ardija', 'Jubilo Iwata', 'true', '9.5', '1.80', '1.90', 'false', '13.5', '4.90', '1.13', 'false', '10.5', '2.25', '1.57']
# ['20211030SAT4', '2021-Oct-30', '13:00:00', 'Japanese Division 2 [JD2]', 'FC Ehime', 'Kyoto Sanga', 'true', '10.5', '2.10', '1.65', 'false', '11.5', '2.65', '1.42', 'false', '13.5', '4.40', '1.16']
# ['20211030SAT5', '2021-Oct-30', '13:00:00', 'Japanese Division 2 [JD2]', 'Giravanz Kitakyushu', 'SC Sagamihara', 'false', '9.5', '2.40', '1.50', 'false', '11.5', '4.15', '1.18', 'true', '8.5', '1.85', '1.85']
# ['20211030SAT6', '2021-Oct-30', '13:00:00', 'Japanese Division 2 [JD2]', 'JEF United Chiba', 'Renofa Yamaguchi', 'true', '9.5', '2.00', '1.72', 'false', '12.5', '4.40', '1.16', 'false', '10.5', '2.55', '1.45']
# ['20211030SAT7', '2021-Oct-30', '13:00:00', 'Japanese Division 2 [JD2]', 'Thespakusatsu Gunma', 'Matsumoto Yamaga', 'false', '13.5', '4.75', '1.14', 'true', '9.5', '1.75', '1.95', 'false', '10.5', '2.20', '1.59']
# ['20211030SAT8', '2021-Oct-30', '13:00:00', 'Japanese Division 2 [JD2]', 'V-Varen Nagasaki', 'Mito Hollyhock', 'false', '13.5', '4.90', '1.13', 'false', '10.5', '2.25', '1.57', 'true', '9.5', '1.80', '1.90']
# ['20211030SAT9', '2021-Oct-30', '13:00:00', 'Korean Division 1 [KD1]', 'Incheon Utd', 'FC Seoul', 'false', '11.5', '4.90', '1.13', 'false', '9.5', '2.90', '1.35', 'true', '8.5', '2.15', '1.62']
# ['20211030SAT10', '2021-Oct-30', '14:00:00', 'Japanese Division 2 [JD2]', 'Tokyo Verdy', 'Ventforet Kofu', 'true', '9.5', '2.02', '1.70', 'false', '12.5', '4.40', '1.16', 'false', '10.5', '2.60', '1.43']
# ['20211030SAT11', '2021-Oct-30', '15:30:00', 'Korean Division 1 [KD1]', 'Suwon Bluewings', 'Jeonbuk Motors', 'false', '9.5', '2.65', '1.42', 'true', '8.5', '2.02', '1.70', 'false', '11.5', '4.55', '1.15']
# ['20211030SAT12', '2021-Oct-30', '17:30:00', 'Japanese Division 2 [JD2]', 'FC Ryukyu', 'Machida Zelvia', 'false', '10.5', '2.50', '1.46', 'false', '12.5', '4.15', '1.18', 'true', '9.5', '1.95', '1.75']
# ['20211030SAT13', '2021-Oct-30', '18:00:00', 'Korean Division 1 [KD1]', 'Seongnam FC', 'Pohang Steelers', 'false', '10.5', '4.05', '1.19', 'true', '8.5', '2.33', '1.53', 'false', '9.5', '3.15', '1.30']
# ['20211030SAT14', '2021-Oct-30', '19:00:00', 'Russian Premier [RPL]', 'Rubin Kazan', 'CSKA Moscow', 'false', '10.5', '2.50', '1.46', 'true', '9.5', '1.95', '1.75', 'false', '12.5', '3.90', '1.20']
# ['20211030SAT15', '2021-Oct-30', '19:30:00', 'Eng Premier [EPL]', 'Leicester', 'Arsenal', 'false', '11.5', '2.48', '1.47', 'false', '14.5', '5.55', '1.10', 'true', '10.5', '1.95', '1.75']
# ['20211030SAT17', '2021-Oct-30', '19:30:00', 'German Division 2 [GD2]', 'Dresden', 'Sandhausen', 'false', '13.5', '5.10', '1.12', 'false', '10.5', '2.25', '1.57', 'true', '9.5', '1.80', '1.90']
# ['20211030SAT18', '2021-Oct-30', '19:30:00', 'German Division 2 [GD2]', 'Hannover', 'Aue', 'true', '9.5', '1.90', '1.80', 'false', '10.5', '2.35', '1.52', 'false', '13.5', '5.55', '1.10']
# ['20211030SAT19', '2021-Oct-30', '19:30:00', 'German Division 2 [GD2]', 'Werder Bremen', 'St. Pauli', 'false', '13.5', '4.40', '1.16', 'false', '11.5', '2.60', '1.43', 'true', '10.5', '2.10', '1.65']
# ['20211030SAT20', '2021-Oct-30', '20:00:00', 'Spanish Division 1 [SFL]', 'CF Elche', 'Real Madrid', 'false', '10.5', '2.48', '1.47', 'true', '9.5', '1.92', '1.78', 'false', '13.5', '5.55', '1.10']
# ['20211030SAT21', '2021-Oct-30', '21:00:00', 'Italian Division 1 [ISA]', 'Atalanta', 'Lazio', 'false', '10.5', '2.40', '1.50', 'false', '12.5', '4.05', '1.19', 'true', '9.5', '1.90', '1.80']
# ['20211030SAT25', '2021-Oct-30', '21:30:00', 'German Division 1 [GSL]', 'Union Berlin', 'Bayern Munich', 'false', '10.5', '2.29', '1.55', 'true', '9.5', '1.82', '1.88', 'false', '13.5', '4.90', '1.13']
# ['20211030SAT26', '2021-Oct-30', '21:30:00', 'German Division 1 [GSL]', 'Bielefeld', 'Mainz', 'false', '12.5', '4.75', '1.14', 'false', '10.5', '2.70', '1.40', 'true', '9.5', '2.10', '1.65']
# ['20211030SAT27', '2021-Oct-30', '21:30:00', 'German Division 1 [GSL]', 'Dortmund', 'Cologne', 'false', '10.5', '2.30', '1.54', 'false', '13.5', '4.90', '1.13', 'true', '9.5', '1.85', '1.85']
# ['20211030SAT28', '2021-Oct-30', '21:30:00', 'German Division 1 [GSL]', 'Freiburg', 'Greuther Furth', 'true', '9.5', '1.85', '1.85', 'false', '12.5', '3.90', '1.20', 'false', '10.5', '2.35', '1.52']
# ['20211030SAT29', '2021-Oct-30', '21:30:00', 'German Division 1 [GSL]', 'Leverkusen', 'Wolfsburg', 'true', '9.5', '1.75', '1.95', 'false', '10.5', '2.20', '1.59', 'false', '13.5', '4.75', '1.14']
# ['20211030SAT30', '2021-Oct-30', '21:30:00', 'Russian Premier [RPL]', 'Spartak Moscow', 'Rostov', 'false', '12.5', '4.30', '1.17', 'false', '10.5', '2.68', '1.41', 'true', '9.5', '2.05', '1.68']
# ['20211030SAT31', '2021-Oct-30', '22:00:00', 'Eng Premier [EPL]', 'Liverpool', 'Brighton', 'false', '12.5', '2.50', '1.46', 'true', '11.5', '1.98', '1.73', 'false', '15.5', '5.30', '1.11']
# ['20211030SAT32', '2021-Oct-30', '22:00:00', 'Eng Premier [EPL]', 'Manchester City', 'Crystal Palace', 'false', '15.5', '5.55', '1.10', 'false', '12.5', '2.60', '1.43', 'true', '11.5', '2.05', '1.68']
# ['20211030SAT33', '2021-Oct-30', '22:00:00', 'Eng Premier [EPL]', 'Newcastle', 'Chelsea', 'false', '11.5', '2.48', '1.47', 'false', '14.5', '5.55', '1.10', 'true', '10.5', '1.95', '1.75']
# ['20211030SAT34', '2021-Oct-30', '22:00:00', 'Eng Premier [EPL]', 'Burnley', 'Brentford', 'false', '13.5', '4.75', '1.14', 'true', '10.5', '2.10', '1.65', 'false', '11.5', '2.70', '1.40']
# ['20211030SAT35', '2021-Oct-30', '22:00:00', 'Eng Premier [EPL]', 'Watford', 'Southampton', 'false', '13.5', '4.30', '1.17', 'true', '10.5', '2.02', '1.70', 'false', '11.5', '2.60', '1.43']
# ['20211030SAT63', '2021-Oct-30', '22:15:00', 'Spanish Division 1 [SFL]', 'Sevilla', 'Osasuna', 'false', '8.5', '2.10', '1.65', 'false', '11.5', '4.90', '1.13', 'true', '7.5', '1.67', '2.07']
# ['20211030SAT67', '2021-Oct-30', '23:00:00', 'French Division 1 [FFL]', 'Metz', 'St. Etienne', 'false', '10.5', '2.45', '1.48', 'false', '12.5', '4.15', '1.18', 'true', '9.5', '1.93', '1.77']
# ['20211030SAT69', '2021-Oct-31', '00:00:00', 'Italian Division 1 [ISA]', 'Verona', 'Juventus', 'true', '10.5', '2.22', '1.58', 'false', '11.5', '2.88', '1.36', 'false', '13.5', '4.90', '1.13']
# ['20211030SAT71', '2021-Oct-31', '00:00:00', 'Russian Premier [RPL]', 'FC Nizhny Novgorod', 'Lokomotiv Moscow', 'true', '9.5', '1.75', '1.95', 'false', '10.5', '2.20', '1.59', 'false', '13.5', '4.40', '1.16']
# ['20211030SAT72', '2021-Oct-31', '00:00:00', 'Russian Premier [RPL]', 'FK Krasnodar', 'Krylya Sovetov Samara', 'false', '11.5', '2.68', '1.41', 'true', '10.5', '2.07', '1.67', 'false', '13.5', '4.15', '1.18']
# ['20211030SAT75', '2021-Oct-31', '00:30:00', 'Eng Premier [EPL]', 'Tottenham', 'Manchester Utd', 'true', '10.5', '1.83', '1.87', 'false', '11.5', '2.29', '1.55', 'false', '14.5', '4.90', '1.13']
# ['20211030SAT76', '2021-Oct-31', '00:30:00', 'Spanish Division 1 [SFL]', 'Valencia', 'Villarreal', 'false', '13.5', '6.50', '1.07', 'false', '9.5', '2.20', '1.59', 'true', '8.5', '1.73', '1.98']
# ['20211030SAT77', '2021-Oct-31', '00:30:00', 'German Division 1 [GSL]', 'Frankfurt', 'RB Leipzig', 'false', '13.5', '4.40', '1.16', 'false', '11.5', '2.65', '1.42', 'true', '10.5', '2.07', '1.67']
# ['20211030SAT89', '2021-Oct-31', '01:30:00', 'US Football League [MLS]', 'Inter Miami CF', 'New York City', 'false', '10.5', '2.40', '1.50', 'false', '12.5', '4.05', '1.19', 'true', '9.5', '1.90', '1.80']
# ['20211030SAT93', '2021-Oct-31', '02:30:00', 'German Division 2 [GD2]', 'Hamburg', 'Holstein Kiel', 'true', '10.5', '1.95', '1.75', 'false', '11.5', '2.40', '1.50', 'false', '14.5', '5.30', '1.11']
# ['20211030SAT94', '2021-Oct-31', '02:45:00', 'Italian Division 1 [ISA]', 'AC Torino', 'Sampdoria', 'true', '10.5', '2.13', '1.63', 'false', '13.5', '4.55', '1.15', 'false', '11.5', '2.70', '1.40']
# ['20211030SAT98', '2021-Oct-31', '03:00:00', 'Spanish Division 1 [SFL]', 'Barcelona', 'Alaves', 'false', '14.5', '6.50', '1.07', 'true', '9.5', '1.83', '1.87', 'false', '10.5', '2.33', '1.53']
# ['20211030SAT99', '2021-Oct-31', '03:00:00', 'French Division 1 [FFL]', 'Lyon', 'Lens', 'false', '13.5', '4.90', '1.13', 'false', '10.5', '2.20', '1.59', 'true', '9.5', '1.77', '1.93']
# ['20211030SAT103', '2021-Oct-31', '03:30:00', 'US Football League [MLS]', 'Real Salt Lake', 'San Jose Earthquakes', 'false', '11.5', '2.65', '1.42', 'true', '10.5', '2.05', '1.68', 'false', '13.5', '4.30', '1.17']
# ['20211030SAT105', '2021-Oct-31', '04:00:00', 'US Football League [MLS]', 'New York Red Bulls', 'CF Montreal', 'true', '9.5', '1.85', '1.85', 'false', '10.5', '2.35', '1.52', 'false', '13.5', '5.30', '1.11']
# ['20211030SAT111', '2021-Oct-31', '06:00:00', 'US Football League [MLS]', 'Atlanta Utd', 'Toronto FC', 'true', '9.5', '1.95', '1.75', 'false', '12.5', '4.15', '1.18', 'false', '10.5', '2.50', '1.46']
# ['20211030SAT113', '2021-Oct-31', '06:15:00', 'Brazilian Division 1 [BD1]', 'Juventude', 'Bahia', 'true', '10.5', '2.20', '1.59', 'false', '11.5', '2.80', '1.38', 'false', '13.5', '4.90', '1.13']
# ['20211030SAT115', '2021-Oct-31', '07:30:00', 'US Football League [MLS]', 'DC United', 'Columbus Crew', 'false', '11.5', '2.65', '1.42', 'false', '13.5', '4.30', '1.17', 'true', '10.5', '2.05', '1.68']
# ['20211030SAT117', '2021-Oct-31', '08:00:00', 'US Football League [MLS]', 'FC Dallas', 'Austin FC', 'false', '12.5', '2.75', '1.39', 'false', '14.5', '4.55', '1.15', 'true', '11.5', '2.19', '1.60']
# ['20211031SUN1', '2021-Oct-31', '12:00:00', 'Japanese Division 2 [JD2]', 'Fagiano Okayama', 'Albirex Niigata', 'true', '8.5', '1.85', '1.85', 'false', '11.5', '4.15', '1.18', 'false', '9.5', '2.40', '1.50']
# ['20211031SUN2', '2021-Oct-31', '13:00:00', 'Japanese Division 2 [JD2]', 'Tochigi SC', 'Montedio Yamagata', 'true', '9.5', '1.93', '1.77', 'false', '10.5', '2.50', '1.46', 'false', '12.5', '4.15', '1.18']
# ['20211031SUN3', '2021-Oct-31', '13:00:00', 'Korean Division 1 [KD1]', 'Daegu FC', 'Jeju Utd', 'false', '12.5', '5.10', '1.12', 'true', '9.5', '2.29', '1.55', 'false', '10.5', '3.00', '1.33']
# ['20211031SUN4', '2021-Oct-31', '15:30:00', 'Korean Division 1 [KD1]', 'Ulsan Hyundai', 'Suwon FC', 'false', '12.5', '5.30', '1.11', 'true', '8.5', '1.82', '1.88', 'false', '9.5', '2.30', '1.54']
# ['20211031SUN5', '2021-Oct-31', '18:00:00', 'Korean Division 1 [KD1]', 'Gwangju FC', 'Gangwon FC', 'true', '8.5', '2.10', '1.65', 'false', '11.5', '4.90', '1.13', 'false', '9.5', '2.80', '1.38']
# ['20211031SUN6', '2021-Oct-31', '19:00:00', 'Russian Premier [RPL]', 'Ufa', 'Akhmat Grozny', 'true', '9.5', '1.77', '1.93', 'false', '10.5', '2.22', '1.58', 'false', '13.5', '4.55', '1.15']
# ['20211031SUN7', '2021-Oct-31', '19:15:00', 'Dutch Division 1 [DFL]', 'Sparta Rotterdam', 'Feyenoord', 'false', '13.5', '4.05', '1.19', 'true', '10.5', '2.02', '1.70', 'false', '11.5', '2.50', '1.46']
# ['20211031SUN8', '2021-Oct-31', '19:30:00', 'Italian Division 1 [ISA]', 'Inter Milan', 'Udinese', 'false', '13.5', '4.90', '1.13', 'false', '11.5', '2.88', '1.36', 'true', '10.5', '2.22', '1.58']
# ['20211031SUN9', '2021-Oct-31', '20:00:00', 'French Division 1 [FFL]', 'Angers SCO', 'Nice', 'true', '9.5', '2.02', '1.70', 'false', '10.5', '2.60', '1.43', 'false', '12.5', '4.55', '1.15']
# ['20211031SUN12', '2021-Oct-31', '20:30:00', 'German Division 2 [GD2]', 'Karlsruher', 'Paderborn', 'false', '13.5', '5.10', '1.12', 'false', '10.5', '2.25', '1.57', 'true', '9.5', '1.80', '1.90']
# ['20211031SUN13', '2021-Oct-31', '20:30:00', 'German Division 2 [GD2]', 'Ingolstadt', 'Jahn Regensburg', 'true', '9.5', '2.00', '1.72', 'false', '12.5', '4.40', '1.16', 'false', '10.5', '2.50', '1.46']
# ['20211031SUN14', '2021-Oct-31', '20:30:00', 'German Division 2 [GD2]', 'Rostock', 'Dusseldorf', 'true', '9.5', '1.75', '1.95', 'false', '10.5', '2.15', '1.62', 'false', '13.5', '4.70', '1.14']
# ['20211031SUN15', '2021-Oct-31', '21:00:00', 'Spanish Division 1 [SFL]', 'Cadiz', 'Mallorca', 'false', '9.5', '2.29', '1.55', 'false', '12.5', '5.30', '1.11', 'true', '8.5', '1.78', '1.92']
# ['20211031SUN18', '2021-Oct-31', '21:30:00', 'Russian Premier [RPL]', 'Arsenal Tula', 'PFC Sochi', 'true', '9.5', '1.85', '1.85', 'false', '13.5', '4.90', '1.13', 'false', '10.5', '2.35', '1.52']
# ['20211031SUN19', '2021-Oct-31', '22:00:00', 'Eng Premier [EPL]', 'Norwich', 'Leeds', 'false', '14.5', '4.55', '1.15', 'false', '12.5', '2.83', '1.37', 'true', '11.5', '2.20', '1.59']
# ['20211031SUN20', '2021-Oct-31', '22:00:00', 'Italian Division 1 [ISA]', 'Fiorentina', 'Spezia', 'false', '12.5', '4.40', '1.16', 'false', '10.5', '2.60', '1.43', 'true', '9.5', '2.00', '1.72']
# ['20211031SUN21', '2021-Oct-31', '22:00:00', 'Italian Division 1 [ISA]', 'Sassuolo', 'Empoli', 'true', '10.5', '1.85', '1.85', 'false', '14.5', '4.90', '1.13', 'false', '11.5', '2.33', '1.53']
# ['20211031SUN22', '2021-Oct-31', '22:00:00', 'Italian Division 1 [ISA]', 'Genoa', 'Venezia', 'false', '10.5', '2.65', '1.42', 'false', '12.5', '4.40', '1.16', 'true', '9.5', '2.02', '1.70']
# ['20211031SUN23', '2021-Oct-31', '22:00:00', 'French Division 1 [FFL]', 'Bordeaux', 'Reims', 'false', '12.5', '4.40', '1.16', 'true', '9.5', '2.00', '1.72', 'false', '10.5', '2.55', '1.45']
# ['20211031SUN24', '2021-Oct-31', '22:00:00', 'French Division 1 [FFL]', 'Montpellier', 'Nantes', 'false', '10.5', '2.25', '1.57', 'true', '9.5', '1.80', '1.90', 'false', '13.5', '5.10', '1.12']
# ['20211031SUN25', '2021-Oct-31', '22:00:00', 'French Division 1 [FFL]', 'Strasbourg', 'Lorient', 'true', '9.5', '1.90', '1.80', 'false', '10.5', '2.40', '1.50', 'false', '12.5', '4.05', '1.19']
# ['20211031SUN26', '2021-Oct-31', '22:00:00', 'French Division 1 [FFL]', 'Troyes', 'Rennes', 'true', '9.5', '2.00', '1.72', 'false', '10.5', '2.55', '1.45', 'false', '12.5', '4.40', '1.16']
# ['20211031SUN28', '2021-Oct-31', '22:30:00', 'German Division 1 [GSL]', 'Augsburg', 'Stuttgart', 'false', '10.5', '2.55', '1.45', 'false', '12.5', '4.40', '1.16', 'true', '9.5', '2.00', '1.72']
# ['20211031SUN30', '2021-Oct-31', '23:15:00', 'Spanish Division 1 [SFL]', 'Atletico Madrid', 'Betis', 'true', '9.5', '1.87', '1.83', 'false', '13.5', '5.30', '1.11', 'false', '10.5', '2.38', '1.51']
# ['20211031SUN35', '2021-Nov-01', '00:00:00', 'French Division 1 [FFL]', 'Brest', 'Monaco', 'false', '10.5', '2.40', '1.50', 'false', '12.5', '4.05', '1.19', 'true', '9.5', '1.90', '1.80']
# ['20211031SUN36', '2021-Nov-01', '00:00:00', 'Russian Premier [RPL]', 'Khimki', 'Ural Yekaterinburg', 'true', '9.5', '1.77', '1.93', 'false', '10.5', '2.22', '1.58', 'false', '13.5', '4.55', '1.15']
# ['20211031SUN37', '2021-Nov-01', '00:30:00', 'Eng Premier [EPL]', 'Aston Villa', 'West Ham', 'true', '10.5', '1.85', '1.85', 'false', '14.5', '4.90', '1.13', 'false', '11.5', '2.33', '1.53']
# ['20211031SUN38', '2021-Nov-01', '00:30:00', 'German Division 1 [GSL]', 'Monchengladbach', 'Bochum', 'false', '13.5', '4.90', '1.13', 'false', '10.5', '2.30', '1.54', 'true', '9.5', '1.87', '1.83']
# ['20211031SUN41', '2021-Nov-01', '01:00:00', 'Italian Division 1 [ISA]', 'Salernitana', 'Napoli', 'false', '11.5', '2.84', '1.37', 'true', '10.5', '2.20', '1.59', 'false', '13.5', '4.75', '1.14']
# ['20211031SUN43', '2021-Nov-01', '01:00:00', 'US Football League [MLS]', 'Minnesota Utd', 'Sporting Kansas City', 'true', '10.5', '2.08', '1.66', 'false', '13.5', '4.40', '1.16', 'false', '11.5', '2.65', '1.42']
# ['20211031SUN49', '2021-Nov-01', '01:30:00', 'Spanish Division 1 [SFL]', 'Getafe', 'Espanyol', 'false', '9.5', '2.40', '1.50', 'true', '8.5', '1.85', '1.85', 'false', '12.5', '5.30', '1.11']
# ['20211031SUN57', '2021-Nov-01', '03:00:00', 'US Football League [MLS]', 'Houston Dynamo', 'Colorado Rapids', 'false', '13.5', '4.15', '1.18', 'true', '10.5', '2.00', '1.72', 'false', '11.5', '2.55', '1.45']
# ['20211031SUN60', '2021-Nov-01', '03:45:00', 'Italian Division 1 [ISA]', 'Roma', 'AC Milan', 'false', '11.5', '2.60', '1.43', 'true', '10.5', '2.04', '1.69', 'false', '13.5', '4.30', '1.17']
# ['20211031SUN61', '2021-Nov-01', '03:45:00', 'French Division 1 [FFL]', 'Clermont', 'Marseille', 'true', '9.5', '2.02', '1.70', 'false', '10.5', '2.60', '1.43', 'false', '12.5', '4.55', '1.15']
# ['20211031SUN62', '2021-Nov-01', '04:00:00', 'Spanish Division 1 [SFL]', 'Real Sociedad', 'Bilbao', 'false', '9.5', '2.33', '1.53', 'false', '12.5', '5.30', '1.11', 'true', '8.5', '1.80', '1.90']
# ['20211031SUN64', '2021-Nov-01', '04:00:00', 'US Football League [MLS]', 'Orlando City', 'Nashville SC', 'true', '9.5', '1.88', '1.82', 'false', '12.5', '4.05', '1.19', 'false', '10.5', '2.40', '1.50']
# ['20211031SUN68', '2021-Nov-01', '05:15:00', 'Brazilian Division 1 [BD1]', 'Sao Paulo', 'Internacional', 'true', '10.5', '1.95', '1.75', 'false', '11.5', '2.40', '1.50', 'false', '13.5', '4.15', '1.18']
# ['20211031SUN72', '2021-Nov-01', '07:30:00', 'US Football League [MLS]', 'Philadelphia Union', 'FC Cincinnati', 'false', '13.5', '5.10', '1.12', 'true', '10.5', '2.29', '1.55', 'false', '11.5', '2.95', '1.34']
# ['20211101MON3', '2021-Nov-02', '01:30:00', 'Spanish Division 1 [SFL]', 'Vallecano', 'Celta Vigo', 'true', '8.5', '1.90', '1.80', 'false', '9.5', '2.48', '1.47', 'false', '12.5', '5.55', '1.10']
# ['20211101MON11', '2021-Nov-02', '03:45:00', 'Italian Division 1 [ISA]', 'Bologna', 'Cagliari', 'false', '11.5', '2.70', '1.40', 'true', '10.5', '2.13', '1.63', 'false', '13.5', '4.55', '1.15']
# ['20211101MON13', '2021-Nov-02', '04:00:00', 'Eng Premier [EPL]', 'Wolves', 'Everton', 'false', '14.5', '5.55', '1.10', 'true', '10.5', '1.95', '1.75', 'false', '11.5', '2.48', '1.47']
# ['20211101MON14', '2021-Nov-02', '04:00:00', 'Spanish Division 1 [SFL]', 'Levante', 'CF Granada', 'false', '13.5', '5.30', '1.11', 'true', '9.5', '1.93', '1.77', 'false', '10.5', '2.50', '1.46']
# ['20211101MON19', '2021-Nov-02', '08:30:00', 'Brazilian Division 1 [BD1]', 'Corinthians', 'Chapecoense', 'false', '13.5', '4.15', '1.18', 'true', '10.5', '1.95', '1.75', 'false', '11.5', '2.40', '1.50']
# ['20211101MON20', '2021-Nov-02', '10:00:00', 'US Football League [MLS]', 'Seattle Sounders', 'LA Galaxy', 'false', '11.5', '2.60', '1.43', 'true', '10.5', '2.02', '1.70', 'false', '13.5', '4.55', '1.15']

# %%
cols_match = ['MatchDay', 'Date', 'Time', 'LeagueJC', 'HomeTeamJC', 'AwayTeamJC']
cols_odds0 = ['MAINLINE_0', 'CHL_LINE_0', 'CHL_H_0', 'CHL_L_0']
cols_odds1 = ['MAINLINE_1', 'CHL_LINE_1', 'CHL_H_1', 'CHL_L_1']
cols_odds2 = ['MAINLINE_2', 'CHL_LINE_2', 'CHL_H_2', 'CHL_L_2']
cols_odds  = ['MAINLINE', 'CHL_LINE', 'CHL_H', 'CHL_L']
cols_pred  = ['prob_0', 'prob_1', 'prob_2', 'total_count']

cols = cols_match + cols_odds0 + cols_odds1 + cols_odds2

# %%
odds = pd.DataFrame(odds, columns=cols)
odds = odds.fillna(value=np.nan)

# %%
cols_odds_ = cols_odds0[1:]+cols_odds1[1:]+cols_odds2[1:]
odds[cols_odds_] = odds[cols_odds_].astype(float)

# %%
odds['MatchDay'] = odds['MatchDay'].str[8:]
odds['Date'] = pd.to_datetime(odds['Date'])
odds['Time'] = pd.to_datetime(odds['Time'], format='%H:%M:%S').dt.time

# %%
odds['DateTimeJC'] = pd.to_datetime(odds['Date'].dt.date.map(str) + '-' + odds['Time'].map(str))
odds['DateTimeJC'] = odds['DateTimeJC'].dt.tz_localize('Hongkong')
odds['DateTime'] = odds['DateTimeJC'].dt.tz_convert('GB')

# %%
map_league = pd.read_csv(path_data/'league.csv')
map_team = pd.read_csv(path_data/'team.csv')

# %%
# Map Div name
odds = odds.merge(map_league[['LeagueJC', 'Div']], 'inner', on='LeagueJC')

# %%
# Map Team name
odds = odds.merge(map_team[['TeamNameJC', 'TeamName']].rename(columns={'TeamName':'HomeTeam'}), 'inner', 
                  left_on='HomeTeamJC', right_on='TeamNameJC').drop(columns=['TeamNameJC'])
odds = odds.merge(map_team[['TeamNameJC', 'TeamName']].rename(columns={'TeamName':'AwayTeam'}), 'inner', 
                  left_on='AwayTeamJC', right_on='TeamNameJC').drop(columns=['TeamNameJC'])

# %% [markdown]
# ## Download recent stats

# %%
# Download latest results in current season
# !wget -q https://www.football-data.co.uk/mmz4281/{SEASON}{int(SEASON)+1}/data.zip -O raw_data/data.zip

# Unzip to folder
# !unzip -q -o raw_data/data.zip -d raw_data/{SEASON}

# %%
usecols = ['Div', 'Date', 'HomeTeam', 'AwayTeam', 'HC', 'AC', 'FTHG', 'FTAG', 'HS', 'AS', 'HST', 'AST']
dtype = {'HC':'float', 'AC':'float'}
parse_dates = ['Date']

seasons = [SEASON]

dfs = []

for folder in sorted(path_raw.iterdir()):
    if folder.is_dir() and folder.name in seasons: 
        for file in sorted(folder.glob('*.csv')):
            try:
                df = pd.read_csv(file, usecols=usecols, dtype=dtype, parse_dates=parse_dates, dayfirst=True)
                df['Season'] = folder.name
                dfs.append(df)
            except:
                continue

# %%
df_season = pd.concat(dfs)
df_season = df_season.dropna()
df_season = df_season.sort_values(['Div', 'Date', 'HomeTeam']).reset_index(drop=True)

# %%
df_hist = pd.read_csv(path_data/'data.csv', dtype={'HC':'float', 'AC':'float'}, parse_dates=['Date'])
df_hist = df_hist.query(f'Season == {int(SEASON)-1}').reset_index(drop=True)

# %%
df_season = pd.concat([df_hist[df_season.columns], df_season])

# %%
# Make features on historical stats (Home and Away)
stats = ['FTHG', 'HS', 'HST', 'HC', 'FTAG', 'AS', 'AST', 'AC']
df_home, df_away = joinLastGamesStatsHomeAway(df_season, stats)

# %%
# Make features on historical stats (For and Against)
stats = [('FTHG', 'FTAG', 'FTG'), ('HS', 'AS', 'S'), ('HST', 'AST', 'ST'), ('HC', 'AC', 'C')]
df_for, df_against = joinLastGamesStatsForAgainst(df_season, stats)

# %%
df_home = df_home.sort_values(['HomeTeam', 'Date']).reset_index(drop=True)
df_away = df_away.sort_values(['AwayTeam', 'Date']).reset_index(drop=True)

df_home = df_home.groupby('HomeTeam')[df_home.columns[df_home.columns.str.contains('Avg')]].last().reset_index()
df_away = df_away.groupby('AwayTeam')[df_away.columns[df_away.columns.str.contains('Avg')]].last().reset_index()

# %%
odds = odds.merge(df_home, 'left', 'HomeTeam').merge(df_away, 'left', 'AwayTeam')

# %%
cols_home = df_for.columns[df_for.columns.str.contains('Avg')]
cols_home = dict(zip(cols_home, 'Home'+cols_home))
cols_home.update({'Team':'HomeTeam'})

cols_away = df_for.columns[df_for.columns.str.contains('Avg')]
cols_away = dict(zip(cols_home, 'Away'+cols_away))
cols_away.update({'Team':'AwayTeam'})

df_for = df_for.groupby('Team')[df_for.columns[df_for.columns.str.contains('Avg')]].last().reset_index()
odds = odds.merge(df_for.rename(columns=cols_home), 'left', 'HomeTeam').merge(df_for.rename(columns=cols_away), 'left', 'AwayTeam')

# %%
cols_home = df_against.columns[df_against.columns.str.contains('Avg')]
cols_home = dict(zip(cols_home, 'Home'+cols_home))
cols_home.update({'Team':'HomeTeam'})

cols_away = df_against.columns[df_against.columns.str.contains('Avg')]
cols_away = dict(zip(cols_home, 'Away'+cols_away))
cols_away.update({'Team':'AwayTeam'})

df_against = df_against.groupby('Team')[df_against.columns[df_against.columns.str.contains('Avg')]].last().reset_index()
odds = odds.merge(df_against.rename(columns=cols_home), 'left', 'HomeTeam').merge(df_against.rename(columns=cols_away), 'left', 'AwayTeam')

# %%
add_datepart(odds, 'DateTime', prefix='', drop=False);

# %%
display_df(odds.head(5).T)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>MatchDay</th>
#       <td>FRI2</td>
#       <td>FRI3</td>
#       <td>SAT17</td>
#       <td>SAT18</td>
#       <td>SAT19</td>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <td>2021-10-30 00:00:00</td>
#       <td>2021-10-30 00:00:00</td>
#       <td>2021-10-30 00:00:00</td>
#       <td>2021-10-30 00:00:00</td>
#       <td>2021-10-30 00:00:00</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>00:30:00</td>
#       <td>00:30:00</td>
#       <td>19:30:00</td>
#       <td>19:30:00</td>
#       <td>19:30:00</td>
#     </tr>
#     <tr>
#       <th>LeagueJC</th>
#       <td>German Division 2 [GD2]</td>
#       <td>German Division 2 [GD2]</td>
#       <td>German Division 2 [GD2]</td>
#       <td>German Division 2 [GD2]</td>
#       <td>German Division 2 [GD2]</td>
#     </tr>
#     <tr>
#       <th>HomeTeamJC</th>
#       <td>Heidenheim</td>
#       <td>Darmstadt</td>
#       <td>Dresden</td>
#       <td>Hannover</td>
#       <td>Werder Bremen</td>
#     </tr>
#     <tr>
#       <th>AwayTeamJC</th>
#       <td>Schalke 04</td>
#       <td>Nurnberg</td>
#       <td>Sandhausen</td>
#       <td>Aue</td>
#       <td>St. Pauli</td>
#     </tr>
#     <tr>
#       <th>MAINLINE_0</th>
#       <td>false</td>
#       <td>false</td>
#       <td>false</td>
#       <td>true</td>
#       <td>false</td>
#     </tr>
#     <tr>
#       <th>CHL_LINE_0</th>
#       <td>11.5</td>
#       <td>10.5</td>
#       <td>13.5</td>
#       <td>9.5</td>
#       <td>13.5</td>
#     </tr>
#     <tr>
#       <th>CHL_H_0</th>
#       <td>2.45</td>
#       <td>2.2</td>
#       <td>5.1</td>
#       <td>1.9</td>
#       <td>4.4</td>
#     </tr>
#     <tr>
#       <th>CHL_L_0</th>
#       <td>1.48</td>
#       <td>1.59</td>
#       <td>1.12</td>
#       <td>1.8</td>
#       <td>1.16</td>
#     </tr>
#     <tr>
#       <th>MAINLINE_1</th>
#       <td>true</td>
#       <td>false</td>
#       <td>false</td>
#       <td>false</td>
#       <td>false</td>
#     </tr>
#     <tr>
#       <th>CHL_LINE_1</th>
#       <td>10.5</td>
#       <td>13.5</td>
#       <td>10.5</td>
#       <td>10.5</td>
#       <td>11.5</td>
#     </tr>
#     <tr>
#       <th>CHL_H_1</th>
#       <td>2.0</td>
#       <td>4.9</td>
#       <td>2.25</td>
#       <td>2.35</td>
#       <td>2.6</td>
#     </tr>
#     <tr>
#       <th>CHL_L_1</th>
#       <td>1.72</td>
#       <td>1.13</td>
#       <td>1.57</td>
#       <td>1.52</td>
#       <td>1.43</td>
#     </tr>
#     <tr>
#       <th>MAINLINE_2</th>
#       <td>false</td>
#       <td>true</td>
#       <td>true</td>
#       <td>false</td>
#       <td>true</td>
#     </tr>
#     <tr>
#       <th>CHL_LINE_2</th>
#       <td>14.5</td>
#       <td>9.5</td>
#       <td>9.5</td>
#       <td>13.5</td>
#       <td>10.5</td>
#     </tr>
#     <tr>
#       <th>CHL_H_2</th>
#       <td>5.55</td>
#       <td>1.75</td>
#       <td>1.8</td>
#       <td>5.55</td>
#       <td>2.1</td>
#     </tr>
#     <tr>
#       <th>CHL_L_2</th>
#       <td>1.1</td>
#       <td>1.95</td>
#       <td>1.9</td>
#       <td>1.1</td>
#       <td>1.65</td>
#     </tr>
#     <tr>
#       <th>DateTimeJC</th>
#       <td>2021-10-30 00:30:00+08:00</td>
#       <td>2021-10-30 00:30:00+08:00</td>
#       <td>2021-10-30 19:30:00+08:00</td>
#       <td>2021-10-30 19:30:00+08:00</td>
#       <td>2021-10-30 19:30:00+08:00</td>
#     </tr>
#     <tr>
#       <th>DateTime</th>
#       <td>2021-10-29 17:30:00+01:00</td>
#       <td>2021-10-29 17:30:00+01:00</td>
#       <td>2021-10-30 12:30:00+01:00</td>
#       <td>2021-10-30 12:30:00+01:00</td>
#       <td>2021-10-30 12:30:00+01:00</td>
#     </tr>
#     <tr>
#       <th>Div</th>
#       <td>D2</td>
#       <td>D2</td>
#       <td>D2</td>
#       <td>D2</td>
#       <td>D2</td>
#     </tr>
#     <tr>
#       <th>HomeTeam</th>
#       <td>Heidenheim</td>
#       <td>Darmstadt</td>
#       <td>Dresden</td>
#       <td>Hannover</td>
#       <td>Werder Bremen</td>
#     </tr>
#     <tr>
#       <th>AwayTeam</th>
#       <td>Schalke 04</td>
#       <td>Nurnberg</td>
#       <td>Sandhausen</td>
#       <td>Erzgebirge Aue</td>
#       <td>St Pauli</td>
#     </tr>
#     <tr>
#       <th>FTHGLast5Avg</th>
#       <td>1.0</td>
#       <td>3.2</td>
#       <td>2.0</td>
#       <td>0.8</td>
#       <td>1.4</td>
#     </tr>
#     <tr>
#       <th>HSLast5Avg</th>
#       <td>16.6</td>
#       <td>12.8</td>
#       <td>14.0</td>
#       <td>14.6</td>
#       <td>16.6</td>
#     </tr>
#     <tr>
#       <th>HSTLast5Avg</th>
#       <td>4.4</td>
#       <td>5.6</td>
#       <td>6.75</td>
#       <td>5.6</td>
#       <td>5.8</td>
#     </tr>
#     <tr>
#       <th>HCLast5Avg</th>
#       <td>9.2</td>
#       <td>3.2</td>
#       <td>4.75</td>
#       <td>7.0</td>
#       <td>6.0</td>
#     </tr>
#     <tr>
#       <th>FTAGLast5Avg</th>
#       <td>1.4</td>
#       <td>1.6</td>
#       <td>1.4</td>
#       <td>0.6</td>
#       <td>0.8</td>
#     </tr>
#     <tr>
#       <th>ASLast5Avg</th>
#       <td>12.6</td>
#       <td>12.0</td>
#       <td>11.8</td>
#       <td>9.8</td>
#       <td>9.8</td>
#     </tr>
#     <tr>
#       <th>ASTLast5Avg</th>
#       <td>4.8</td>
#       <td>5.2</td>
#       <td>4.4</td>
#       <td>3.2</td>
#       <td>3.6</td>
#     </tr>
#     <tr>
#       <th>ACLast5Avg</th>
#       <td>3.6</td>
#       <td>4.2</td>
#       <td>5.4</td>
#       <td>3.0</td>
#       <td>3.4</td>
#     </tr>
#     <tr>
#       <th>HomeFTGForLast5Avg</th>
#       <td>1.8</td>
#       <td>2.4</td>
#       <td>0.8</td>
#       <td>1.0</td>
#       <td>1.2</td>
#     </tr>
#     <tr>
#       <th>HomeSForLast5Avg</th>
#       <td>15.0</td>
#       <td>13.4</td>
#       <td>11.2</td>
#       <td>12.4</td>
#       <td>15.2</td>
#     </tr>
#     <tr>
#       <th>HomeSTForLast5Avg</th>
#       <td>4.8</td>
#       <td>6.0</td>
#       <td>3.0</td>
#       <td>3.4</td>
#       <td>4.4</td>
#     </tr>
#     <tr>
#       <th>HomeCForLast5Avg</th>
#       <td>6.6</td>
#       <td>3.6</td>
#       <td>4.0</td>
#       <td>4.6</td>
#       <td>6.0</td>
#     </tr>
#     <tr>
#       <th>AwayFTGForLast5Avg</th>
#       <td>1.6</td>
#       <td>1.2</td>
#       <td>1.2</td>
#       <td>1.0</td>
#       <td>2.8</td>
#     </tr>
#     <tr>
#       <th>AwaySForLast5Avg</th>
#       <td>15.2</td>
#       <td>11.8</td>
#       <td>7.6</td>
#       <td>13.2</td>
#       <td>14.4</td>
#     </tr>
#     <tr>
#       <th>AwaySTForLast5Avg</th>
#       <td>5.6</td>
#       <td>3.8</td>
#       <td>3.0</td>
#       <td>4.4</td>
#       <td>6.6</td>
#     </tr>
#     <tr>
#       <th>AwayCForLast5Avg</th>
#       <td>4.4</td>
#       <td>4.6</td>
#       <td>3.0</td>
#       <td>3.8</td>
#       <td>5.4</td>
#     </tr>
#     <tr>
#       <th>HomeFTGAgainstLast5Avg</th>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>1.4</td>
#       <td>0.6</td>
#       <td>1.6</td>
#     </tr>
#     <tr>
#       <th>HomeSAgainstLast5Avg</th>
#       <td>12.0</td>
#       <td>12.0</td>
#       <td>14.8</td>
#       <td>13.4</td>
#       <td>9.4</td>
#     </tr>
#     <tr>
#       <th>HomeSTAgainstLast5Avg</th>
#       <td>4.2</td>
#       <td>3.6</td>
#       <td>4.8</td>
#       <td>4.0</td>
#       <td>3.8</td>
#     </tr>
#     <tr>
#       <th>HomeCAgainstLast5Avg</th>
#       <td>7.0</td>
#       <td>6.0</td>
#       <td>6.4</td>
#       <td>5.0</td>
#       <td>3.2</td>
#     </tr>
#     <tr>
#       <th>AwayFTGAgainstLast5Avg</th>
#       <td>0.4</td>
#       <td>0.8</td>
#       <td>2.6</td>
#       <td>2.2</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>AwaySAgainstLast5Avg</th>
#       <td>9.4</td>
#       <td>14.6</td>
#       <td>18.8</td>
#       <td>14.0</td>
#       <td>11.2</td>
#     </tr>
#     <tr>
#       <th>AwaySTAgainstLast5Avg</th>
#       <td>2.0</td>
#       <td>4.4</td>
#       <td>7.0</td>
#       <td>4.6</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>AwayCAgainstLast5Avg</th>
#       <td>3.8</td>
#       <td>6.4</td>
#       <td>7.2</td>
#       <td>5.2</td>
#       <td>3.8</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>2021</td>
#       <td>2021</td>
#       <td>2021</td>
#       <td>2021</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>Month</th>
#       <td>10</td>
#       <td>10</td>
#       <td>10</td>
#       <td>10</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>Week</th>
#       <td>43</td>
#       <td>43</td>
#       <td>43</td>
#       <td>43</td>
#       <td>43</td>
#     </tr>
#     <tr>
#       <th>Day</th>
#       <td>29</td>
#       <td>29</td>
#       <td>3

# %% [markdown]
# ## Load model

# %%
learn_bnb = load_learner('models/learn_bnb.pkl')

# %%
to = load_pandas('models/to.pkl')

# %%
def predict(self, row):
    "Predict on a Pandas Series"
    dl = self.dls.test_dl(row.to_frame().T)
    dl.dataset.conts = dl.dataset.conts.astype(np.float32)
    inp,preds,_ = self.get_preds(dl=dl, with_input=True, with_decoded=False)
    b = tuplify(inp)
    full_dec = self.dls.decode(b)
    return full_dec,preds[0]

learn_bnb.predict = MethodType(predict, learn_bnb)

# %%
to_tst = to.new(odds)
to_tst.process()
# to_tst.items.head()

# %%
tst_dl = learn_bnb.dls.valid.new(to_tst)
tst_dl.show(max_n=999)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Div</th>
#       <th>HomeTeam</th>
#       <th>AwayTeam</th>
#       <th>Dayofweek</th>
#       <th>FTHGLast5Avg</th>
#       <th>HSLast5Avg</th>
#       <th>HSTLast5Avg</th>
#       <th>HCLast5Avg</th>
#       <th>FTAGLast5Avg</th>
#       <th>ASLast5Avg</th>
#       <th>ASTLast5Avg</th>
#       <th>ACLast5Avg</th>
#       <th>HomeFTGForLast5Avg</th>
#       <th>HomeSForLast5Avg</th>
#       <th>HomeSTForLast5Avg</th>
#       <th>HomeCForLast5Avg</th>
#       <th>AwayFTGForLast5Avg</th>
#       <th>AwaySForLast5Avg</th>
#       <th>AwaySTForLast5Avg</th>
#       <th>AwayCForLast5Avg</th>
#       <th>HomeFTGAgainstLast5Avg</th>
#       <th>HomeSAgainstLast5Avg</th>
#       <th>HomeSTAgainstLast5Avg</th>
#       <th>HomeCAgainstLast5Avg</th>
#       <th>AwayFTGAgainstLast5Avg</th>
#       <th>AwaySAgainstLast5Avg</th>
#       <th>AwaySTAgainstLast5Avg</th>
#       <th>AwayCAgainstLast5Avg</th>
#       <th>Year</th>
#       <th>Month</th>
#       <th>Week</th>
#       <th>Day</th>
#       <th>Dayofyear</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>D2</td>
#       <td>Heidenheim</td>
#       <td>Schalke 04</td>
#       <td>4</td>
#       <td>1.0</td>
#       <td>16.6</td>
#       <td>4.40</td>
#       <td>9.20</td>
#       <td>1.4</td>
#       <td>12.6</td>
#       <td>4.8</td>
#       <td>3.6</td>
#       <td>1.8</td>
#       <td>15.0</td>
#       <td>4.8</td>
#       <td>6.6</td>
#       <td>1.6</td>
#       <td>15.2</td>
#       <td>5.6</td>
#       <td>4.4</td>
#       <td>2.0</td>
#       <td>12.0</td>
#       <td>4.2</td>
#       <td>7.0</td>
#       <td>0.4</td>
#       <td>9.4</td>
#       <td>2.0</td>
#       <td>3.8</td>
#       <td>2021.0</td>
#       <td>10.0</td>
#       <td>43.0</td>
#       <td>29.0</td>
#       <td>302.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>D2</td>
#       <td>Darmstadt</td>
#       <td>Nurnberg</td>
#       <td>4</td>
#       <td>3.2</td>
#       <td>12.8</td>
#       <td>5.60</td>
#       <td>3.20</td>
#       <td>1.6</td>
#       <td>12.0</td>
#       <td>5.2</td>
#       <td>4.2</td>
#       <td>2.4</td>
#       <td>13.4</td>
#       <td>6.0</td>
#       <td>3.6</td>
#       <td>1.2</td>
#       <td>11.8</td>
#       <td>3.8</td>
#       <td>4.6</td>
#       <td>1.0</td>
#       <td>12.0</td>
#       <td>3.6</td>
#       <td>6.0</td>
#       <td>0.8</td>
#       <td>14.6</td>
#       <td>4.4</td>
#       <td>6.4</td>
#       <td>2021.0</td>
#       <td>10.0</td>
#       <td>43.0</td>
#       <td>29.0</td>
#       <td>302.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>D2</td>
#       <td>Dresden</td>
#       <td>Sandhausen</td>
#       <td>5</td>
#       <td>2.0</td>
#       <td>14.0</td>
#       <td>6.75</td>
#       <td>4.75</td>
#       <td>1.4</td>
#       <td>11.8</td>
#       <td>4.4</td>
#       <td>5.4</td>
#       <td>0.8</td>
#       <td>11.2</td>
#       <td>3.0</td>
#       <td>4.0</td>
#       <td>1.2</td>
#       <td>7.6</td>
#       <td>3.0</td>
#       <td>3.0</td>
#       <td>1.4</td>
#       <td>14.8</td>
#       <td>4.8</td>
#       <td>6.4</td>
#       <td>2.6</td>
#       <td>18.8</td>
#       <td>7.0</td>
#       <td>7.2</td>
#       <td>2021.0</td>
#       <td>10.0</td>
#       <td>43.0</td>
#       <td>30.0</td>
#       <td>303.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>D2</td>
#       <td>Hannover</td>
#       <td>Erzgebirge Aue</td>
#       <td>5</td>
#       <td>0.8</td>
#       <td>14.6</td>
#       <td>5.60</td>
#       <td>7.00</td>
#       <td>0.6</td>
#       <td>9.8</td>
#       <td>3.2</td>
#       <td>3.0</td>
#       <td>1.0</td>
#       <td>12.4</td>
#       <td>3.4</td>
#       <td>4.6</td>
#       <td>1.0</td>
#       <td>13.2</td>
#       <td>4.4</td>
#       <td>3.8</td>
#       <td>0.6</td>
#       <td>13.4</td>
#       <td>4.0</td>
#       <td>5.0</td>
#       <td>2.2</td>
#       <td>14.0</td>
#       <td>4.6</td>
#       <td>5.2</td>
#       <td>2021.0</td>
#       <td>10.0</td>
#       <td>43.0</td>
#       <td>30.0</td>
#       <td>303.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>D2</td>
#       <td>Werder Bremen</td>
#       <td>St Pauli</td>
#       <td>5</td>
#       <td>1.4</td>
#       <td>16.6</td>
#       <td>5.80</td>
#       <td>6.00</td>
#       <td>0.8</td>
#       <td>9.8</td>
#       <td>3.6</td>
#       <td>3.4</td>
#       <td>1.2</td>
#       <td>15.2</td>
#       <td>4.4</td>
#       <td>6.0</td>
#       <td>2.8</td>
#       <td>14.4</td>
#       <td>6.6</td>
#       <td>5.4</td>
#       <td>1.6</td>
#       <td>9.4</td>
#       <td>3.8</td>
#       <td>3.2</td>
#       <td>1.0</td>
#       <td>11.2</td>
#       <td>3.0</td>
#       <td>3.8</td>
#       <td>2021.0</td>
#       <td>10.0</td>
#       <td>43.0</td>
#       <td>30.0</td>
#       <td>303.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>D2</td>
#       <td>Hamburg</td>
#       <td>Holstein Kiel</td>
#       <td>5</td>
#       <td>2.2</td>
#       <td>18.0</td>
#       <td>7.00</td>
#       <td>8.80</td>
#       <td>1.6</td>
#       <td>13.0</td>
#       <td>3.8</td>
#       <td>6.0</td>
#       <td>1.6</td>
#       <td>15.2</td>
#       <td>5.6</td>
#       <td>9.4</td>
#       <td>1.0</td>
#       <td>12.4</td>
#       <td>4.0</td>
#       <td>6.2</td>
#       <td>1.0</td>
#       <td>10.6</td>
#       <td>3.0</td>
#       <td>3.6</td>
#       <td>1.8</td>
#       <td>14.6</td>
#       <td>4.4</td>
#       <td>3.8</td>
#       <td>2021.0</td>
#       <td>10.0</td>
#       <td>43.0</td>
#       <td>30.0</td>
#       <td>303.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>D2</td>
#       <td>Karlsruhe</td>
#       <td>Paderborn</td>
#       <td>6</td>
#       <td>1.8</td>
#       <td>15.2</td>
#       <td>4.80</td>
#       <td>5.00</td>
#       <td>2.4</td>
#       <td>14.0</td>
#       <td>5.6</td>
#       <td>4.6</td>
#       <td>1.8</td>
#       <td>14.6</td>
#       <td>4.6</td>
#       <td>5.8</td>
#       <td>1.8</td>
#       <td>15.8</td>
#       <td>5.6</td>
#       <td>4.4</td>
#       <td>1.8</td>
#       <td>13.8</td>
#       <td>4.8</td>
#       <td>2.6</td>
#       <td>1.4</td>
#       <td>18.0</td>
#       <td>7.2</td>
#       <td>5.0</td>
#       <td>2021.0</td>
#       <td>10.0</td>
#       <td>43.0</td>
#       <td>31.0</td>
#       <td>304.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>D2</td>
#       <td>Ingolstadt</td>
#       <td>Regensburg</td>
#       <td>6</td>
#       <td>0.5</td>
#       <td>13.5</td>
#       <td>3.00</td>
#       <td>4.75</td>
#       <td>1.2</td>
#       <td>9.8</td>
#       <td>3.6</td>
#       <td>4.4</td>
#       <td>0.6</td>
#       <td>11.0</td>
#       <td>1.8</td>
#       <td>3.4</td>
#       <td>1.8</td>
#       <td>14.0</td>
#       <td>5.2</td>
#       <td>3.2</td>
#       <td>2.6</td>
#       <td>13.6</td>
#       <td>5.2</td>
#       <td>5.4</td>
#       <td>1.6</td>
#       <td>14.6</td>
#       <td>5.2</td>
#       <td>4.2</td>
#       <td>2021.0</td>
#       <td>10.0</td>
#       <td>43.0</td>
#       <td>31.0</td>
#       <td>304.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>D2</td>
#       <td>Hansa Rostock</td>
#       <td>Fortuna Dusseldorf</td>
#       <td>6</td>
#       <td>1.0</td>
#       <td>12.5</td>
#       <td>4.25</td>
#       <td>6.00</td>
#       <td>1.2</td>
#       <td>15.8</td>
#       <td>4.2</td>
#       <td>6.8</td>
#       <td>1.0</td>
#       <td>13.2</td>
#       <td>3.6</td>
#       <td>4.8</td>
#       <td>1.4</td>
#       <td>15.0</td>
#       <td>5.0</td>
#       <td>5.4</td>
#       <td>1.0</td>
#       <td>10.4</td>
#       <td>4.6</td>
#       <td>4.8</td>
#       <td>1.2</td>
#       <td>15.4</td>
#       <td>4.6</td>
#       <td>5.2</td>
#       <td>2021.0</td>
#       <td>10.0</td>
#       <td>43.0</td>
#       <td>31.0</td>
#       <td>304.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>D1</td>
#       <td>Hoffenheim</td>
#       <td>Hertha</td>
#       <td>4</td>
#       <td>2.2</td>
#       <td>14.2</td>
#       <td>4.60</td>
#       <td>5.60</td>
#       <td>1.0</td>
#       <td>7.6</td>
#       <td>4.0</td>
#       <td>2.8</td>
#       <td>1.8</td>
#       <td>13.2</td>
#       <td>3.6</td>
#       <td>4.4</td>
#       <td>1.6</td>
#       <td>9.8</td>
#       <td>3.8</td>
#       <td>4.0</td>
#       <td>1.2</td>
#       <td>11.0</td>
#       <td>2.8</td>
#       <td>4.8</td>
#       <td>2.2</td>
#       <td>13.8</td>
#       <td>5.6</td>
#       <td>5.8</td>
#       <td>2021.0</td>
#       <td>10.0</td>
#       <td>43.0</td>
#       <td>29.0</td>
#       <td>302.0</td>
#     </tr>
#     <tr>

# %%
pred, _ = learn_bnb.get_preds(dl=tst_dl)

# %%
probs = F.softmax(pred[:, :3], dim=-1)
total_count = 1 / F.softplus(pred[:, 3:])

# %%
odds[cols_pred] = torch.cat([probs, total_count], dim=-1)

# %%
odds0 = odds[cols_match+cols_odds0+cols_pred].rename(columns=dict(zip(cols_odds0, cols_odds)))
odds1 = odds[cols_match+cols_odds1+cols_pred].rename(columns=dict(zip(cols_odds1, cols_odds)))
odds2 = odds[cols_match+cols_odds2+cols_pred].rename(columns=dict(zip(cols_odds2, cols_odds)))

# %%
odds = pd.concat([odds0, odds1, odds2]).dropna().reset_index(drop=True)
odds['MAINLINE'] = np.where(odds['MAINLINE']=='true', True, False)

# %%
odds.head(10)
# Out:
#   MatchDay       Date      Time                 LeagueJC     HomeTeamJC  \
# 0     FRI2 2021-10-30  00:30:00  German Division 2 [GD2]     Heidenheim
# 1     FRI3 2021-10-30  00:30:00  German Division 2 [GD2]      Darmstadt
# 2    SAT17 2021-10-30  19:30:00  German Division 2 [GD2]        Dresden
# 3    SAT18 2021-10-30  19:30:00  German Division 2 [GD2]       Hannover
# 4    SAT19 2021-10-30  19:30:00  German Division 2 [GD2]  Werder Bremen
# 5    SAT93 2021-10-31  02:30:00  German Division 2 [GD2]        Hamburg
# 6    SUN12 2021-10-31  20:30:00  German Division 2 [GD2]     Karlsruher
# 7    SUN13 2021-10-31  20:30:00  German Division 2 [GD2]     Ingolstadt
# 8    SUN14 2021-10-31  20:30:00  German Division 2 [GD2]        Rostock
# 9     FRI9 2021-10-30  02:30:00  German Division 1 [GSL]     Hoffenheim
#
#         AwayTeamJC  MAINLINE  CHL_LINE  CHL_H  CHL_L    prob_0    prob_1  \
# 0       Schalke 04     False      11.5   2.45   1.48  0.848326  0.077293
# 1         Nurnberg     False      10.5   2.20   1.59  0.822324  0.096388
# 2       Sandhausen     False      13.5   5.10   1.12  0.838060  0.086538
# 3              Aue      True       9.5   1.90   1.80  0.847085  0.096824
# 4        St. Pauli     False      13.5   4.40   1.16  0.849211  0.090457
# 5    Holstein Kiel      True      10.5   1.95   1.75  0.850449  0.085622
# 6        Paderborn     False      13.5   5.10   1.12  0.850045  0.088717
# 7  Jahn Regensburg      True       9.5   2.00   1.72  0.846045  0.074061
# 8       Dusseldorf      True       9.5   1.75   1.95  0.843613  0.103807
# 9    Hertha Berlin      True       9.5   1.80   1.90  0.826060  0.101464
#
#      prob_2  total_count
# 0  0.074381    58.898792
# 1  0.081288    45.031567
# 2  0.075402    44.426243
# 3  0.056091    46.659538
# 4  0.060333    54.170624
# 5  0.063929    61.205872
# 6  0.061238    65.328148
# 7  0.079895    59.042469
# 8  0.052580    52.836399
# 9  0.072477    42.450790

# %%
prob_hilo = []

for r in list(zip(odds['prob_0'], odds['prob_1'], odds['prob_2'], odds['total_count'], odds['CHL_LINE'])):
    probs = torch.tensor(r[0:3], device='cpu')
    total_count = torch.tensor(r[3], device='cpu')

    bnb_corner = BivariateNegativeBinomial(total_count=total_count, probs=probs)
    value = torch.cartesian_prod(torch.arange(0., 15.), torch.arange(0., 15.))
    corner = bnb_corner.log_prob(value).exp()
    
    line = r[4]
    mask = value.sum(-1) < line
    prob_lo = corner[mask].sum()
    prob_hi = 1 - prob_lo
    
    prob_hilo.append([prob_hi.item(), prob_lo.item()])

# %%
odds[['prob_hi', 'prob_lo']] = prob_hilo

# %%
odds['kelly_hi'] = (odds['prob_hi'] * odds['CHL_H'] - 1) / (odds['CHL_H'] - 1)
odds['kelly_lo'] = (odds['prob_lo'] * odds['CHL_L'] - 1) / (odds['CHL_L'] - 1)

# %%
odds['kelly'] = np.where(
    np.maximum(odds['kelly_hi'], odds['kelly_lo']) > 0, 
    np.where(odds['kelly_hi'] > odds['kelly_lo'], odds['kelly_hi'], odds['kelly_lo']), 
    np.nan
)

# %%
odds['bet'] = np.where(
    np.maximum(odds['kelly_hi'], odds['kelly_lo']) > 0, 
    np.where(odds['kelly_hi'] > odds['kelly_lo'], 'High', 'Low'), 
    None
)

# %%
odds = odds.sort_values('kelly', ascending=False).reset_index(drop=True)

# %%
odds['selected'] = np.where(
    odds['MAINLINE']==True, np.where(
        odds['kelly']>0.3, '$$$', np.where(
            odds['kelly']>0.2, '$$', np.where(
                odds['kelly']>0.1, '$', None))), 
    None
)

# %%
odds = odds.drop(columns=cols_pred+['kelly_hi', 'kelly_lo'])

# %%
odds[odds.bet.notna() & odds.selected.notna()]
# Out:
#    MatchDay       Date      Time                  LeagueJC       HomeTeamJC  \
# 3     SAT27 2021-10-30  21:30:00   German Division 1 [GSL]         Dortmund
# 4     SUN12 2021-10-31  20:30:00   German Division 2 [GD2]       Karlsruher
# 10    SAT63 2021-10-30  22:15:00  Spanish Division 1 [SFL]          Sevilla
# 11    SAT17 2021-10-30  19:30:00   German Division 2 [GD2]          Dresden
# 12    SUN13 2021-10-31  20:30:00   German Division 2 [GD2]       Ingolstadt
# 13    SAT18 2021-10-30  19:30:00   German Division 2 [GD2]         Hannover
# 22    SAT35 2021-10-30  22:00:00         Eng Premier [EPL]          Watford
# 23    SAT32 2021-10-30  22:00:00         Eng Premier [EPL]  Manchester City
# 24     FRI9 2021-10-30  02:30:00   German Division 1 [GSL]       Hoffenheim
# 27    SUN38 2021-11-01  00:30:00   German Division 1 [GSL]  Monchengladbach
# 30    SAT31 2021-10-30  22:00:00         Eng Premier [EPL]        Liverpool
# 31    SAT75 2021-10-31  00:30:00         Eng Premier [EPL]        Tottenham
# 33    MON11 2021-11-02  03:45:00  Italian Division 1 [ISA]          Bologna
# 35    SAT69 2021-10-31  00:00:00  Italian Division 1 [ISA]           Verona
#
#          AwayTeamJC  MAINLINE  CHL_LINE  CHL_H  CHL_L   prob_hi   prob_lo  \
# 3           Cologne      True       9.5   1.85   1.85  0.316134  0.683866
# 4         Paderborn      True       9.5   1.80   1.90  0.693715  0.306285
# 10          Osasuna      True       7.5   1.67   2.07  0.696675  0.303325
# 11       Sandhausen      True       9.5   1.80   1.90  0.362267  0.637733
# 12  Jahn Regensburg      True       9.5   2.00   1.72  0.614781  0.385219
# 13              Aue      True       9.5   1.90   1.80  0.342677  0.657323
# 22      Southampton      True      10.5   2.02   1.70  0.344252  0.655748
# 23   Crystal Palace      True      11.5   2.05   1.68  0.340078  0.659922
# 24    Hertha Berlin      True       9.5   1.80   1.90  0.404852  0.595148
# 27           Bochum      True       9.5   1.87   1.83  0.391446  0.608554
# 30         Brighton      True      11.5   1.98   1.73  0.371541  0.628459
# 31   Manchester Utd      True      10.5   1.83   1.87  0.409830  0.590170
# 33         Cagliari      True      10.5   2.13   1.63  0.525858  0.474142
# 35         Juventus      True      10.5   2.22   1.58  0.329717  0.670283
#
#        kelly   bet selected
# 3   0.311945   Low      $$$
# 4   0.310859  High      $$$
# 10  0.243951  High       $$
# 11  0.235214   Low       $$
# 12  0.229562  High       $$
# 13  0.228977   Low       $$
# 22  0.163960   Low        $
# 23  0.159806   Low        $
# 24  0.145313   Low        $
# 27  0.136932   Low        $
# 30  0.119499   Low        $
# 31  0.119101   Low        $
# 33  0.106264  High        $
# 35  0.101806   Low        $

# %%
display_df(odds[odds.MatchDay.isin(odds[odds.bet.notna() & odds.selected.notna()].MatchDay) & odds.bet.notna()])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MatchDay</th>
#       <th>Date</th>
#       <th>Time</th>
#       <th>LeagueJC</th>
#       <th>HomeTeamJC</th>
#       <th>AwayTeamJC</th>
#       <th>MAINLINE</th>
#       <th>CHL_LINE</th>
#       <th>CHL_H</th>
#       <th>CHL_L</th>
#       <th>prob_hi</th>
#       <th>prob_lo</th>
#       <th>kelly</th>
#       <th>bet</th>
#       <th>selected</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>SAT27</td>
#       <td>2021-10-30</td>
#       <td>21:30:00</td>
#       <td>German Division 1 [GSL]</td>
#       <td>Dortmund</td>
#       <td>Cologne</td>
#       <td>False</td>
#       <td>13.5</td>
#       <td>4.90</td>
#       <td>1.13</td>
#       <td>0.055413</td>
#       <td>0.944587</td>
#       <td>0.518335</td>
#       <td>Low</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>SAT27</td>
#       <td>2021-10-30</td>
#       <td>21:30:00</td>
#       <td>German Division 1 [GSL]</td>
#       <td>Dortmund</td>
#       <td>Cologne</td>
#       <td>False</td>
#       <td>10.5</td>
#       <td>2.30</td>
#       <td>1.54</td>
#       <td>0.219785</td>
#       <td>0.780215</td>
#       <td>0.373205</td>
#       <td>Low</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>SAT17</td>
#       <td>2021-10-30</td>
#       <td>19:30:00</td>
#       <td>German Division 2 [GD2]</td>
#       <td>Dresden</td>
#       <td>Sandhausen</td>
#       <td>False</td>
#       <td>13.5</td>
#       <td>5.10</td>
#       <td>1.12</td>
#       <td>0.071448</td>
#       <td>0.928552</td>
#       <td>0.333151</td>
#       <td>Low</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>SAT27</td>
#       <td>2021-10-30</td>
#       <td>21:30:00</td>
#       <td>German Division 1 [GSL]</td>
#       <td>Dortmund</td>
#       <td>Cologne</td>
#       <td>True</td>
#       <td>9.5</td>
#       <td>1.85</td>
#       <td>1.85</td>
#       <td>0.316134</td>
#       <td>0.683866</td>
#       <td>0.311945</td>
#       <td>Low</td>
#       <td>$$$</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>SUN12</td>
#       <td>2021-10-31</td>
#       <td>20:30:00</td>
#       <td>German Division 2 [GD2]</td>
#       <td>Karlsruher</td>
#       <td>Paderborn</td>
#       <td>True</td>
#       <td>9.5</td>
#       <td>1.80</td>
#       <td>1.90</td>
#       <td>0.693715</td>
#       <td>0.306285</td>
#       <td>0.310859</td>
#       <td>High</td>
#       <td>$$$</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>SAT18</td>
#       <td>2021-10-30</td>
#       <td>19:30:00</td>
#       <td>German Division 2 [GD2]</td>
#       <td>Hannover</td>
#       <td>Aue</td>
#       <td>False</td>
#       <td>13.5</td>
#       <td>5.55</td>
#       <td>1.10</td>
#       <td>0.063392</td>
#       <td>0.936608</td>
#       <td>0.302688</td>
#       <td>Low</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>SAT18</td>
#       <td>2021-10-30</td>
#       <td>19:30:00</td>
#       <td>German Division 2 [GD2]</td>
#       <td>Hannover</td>
#       <td>Aue</td>
#       <td>False</td>
#       <td>10.5</td>
#       <td>2.35</td>
#       <td>1.52</td>
#       <td>0.241695</td>
#       <td>0.758305</td>
#       <td>0.293507</td>
#       <td>Low</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>SAT17</td>
#       <td>2021-10-30</td>
#       <td>19:30:00</td>
#       <td>German Division 2 [GD2]</td>
#       <td>Dresden</td>
#       <td>Sandhausen</td>
#       <td>False</td>
#       <td>10.5</td>
#       <td>2.25</td>
#       <td>1.57</td>
#       <td>0.259206</td>
#       <td>0.740794</td>
#       <td>0.286046</td>
#       <td>Low</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>SUN38</td>
#       <td>2021-11-01</td>
#       <td>00:30:00</td>
#       <td>German Division 1 [GSL]</td>
#       <td>Monchengladbach</td>
#       <td>Bochum</td>
#       <td>False</td>
#       <td>13.5</td>
#       <td>4.90</td>
#       <td>1.13</td>
#       <td>0.082454</td>
#       <td>0.917546</td>
#       <td>0.283288</td>
#       <td>Low</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>SUN12</td>
#       <td>2021-10-31</td>
#       <td>20:30:00</td>
#       <td>German Division 2 [GD2]</td>
#       <td>Karlsruher</td>
#       <td>Paderborn</td>
#       <td>False</td>
#       <td>10.5</td>
#       <td>2.25</td>
#       <td>1.57</td>
#       <td>0.587290</td>
#       <td>0.412710</td>
#       <td>0.257122</td>
#       <td>High</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>SAT63</td>
#       <td>2021-10-30</td>
#       <td>22:15:00</td>
#       <td>Spanish Division 1 [SFL]</td>
#       <td>Sevilla</td>
#       <td>Osasuna</td>
#       <td>True</td>
#       <td>7.5</td>
#       <td>1.67</td>
#       <td>2.07</td>
#       <td>0.696675</td>
#       <td>0.303325</td>
#       <td>0.243951</td>
#       <td>High</td>
#       <td>$$</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>SAT17</td>
#       <td>2021-10-30</td>
#       <td>19:30:00</td>
#       <td>German Division 2 [GD2]</td>
#       <td>Dresden</td>
#       <td>Sandhausen</td>
#       <td>True</td>
#       <td>9.5</td>
#       <td>1.80</td>
#       <td>1.90</td>
#       <td>0.362267</td>
#       <td>0.637733</td>
#       <td>0.235214</td>
#       <td>Low</td>
#       <td>$$</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>SUN13</td>
#       <td>2021-10-31</td>
#       <td>20:30:00</td>
#       <td>German Division 2 [GD2]</td>
#       <td>Ingolstadt</td>
#       <td>Jahn Regensburg</td>
#       <td>True</td>
#       <td>9.5</td>
#       <td>2.00</td>
#       <td>1.72</td>
#       <td>0.614781</td>
#       <td>0.385219</td>
#       <td>0.229562</td>
#       <td>High</td>
#       <td>$$</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>SAT18</td>
#       <td>2021-10-30</td>
#       <td>19:30:00</td>
#       <td>German Division 2 [GD2]</td>
#       <td>Hannover</td>
#       <td>Aue</td>
#       <td>True</td>
#       <td>9.5</td>
#       <td>1.90</td>
#       <td>1.80</td>
#       <td>0.342677</td>
#       <td>0.657323</td>
#       <td>0.228977</td>
#       <td>Low</td>
#       <td>$$</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>SAT35</td>
#       <td>2021-10-30</td>
#       <td>22:00:00</td>
#       <td>Eng Premier [EPL]</td>
#       <td>Watford</td>
#       <td>Southampton</td>
#       <td>False</td>
#       <td>13.5</td>
#       <td>4.30</td>
#       <td>1.17</td>
#       <td>0.113539</td>
#       <td>0.886461</td>
#       <td>0.218584</td>
#       <td>Low</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>FRI9</td>
#       <td>2021-10-30</td>
#       <td>02:30:00</td>
#       <td>German Division 1 [GSL]</td>
#       <td>Hoffenheim</td>
#       <td>Hertha Berlin</td>
#       <td>False</td>
#       <td>13.5</td>
#       <td>4.90</td>
#       <td>1.13</td>
#       <td>0.090112</td>
#       <td>0.909888</td>
#       <td>0.216719</td>
#       <td>Low</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>SAT63</td>
#       <td>2021-10-30</td>
#       <td>22:15:00</td>
#       <td>Spanish Division 1 [SFL]</td>
#       <td>Sevilla</td>
#       <td>Osasuna</td>
#       <td>False</td>
#       <td>8.5</td>
#       <td>2.10</td>
#       <td>1.65</td>
#       <td>0.577929</td>
#       <td>0.422071</td>
#       <td>0.194227</td>
#       <td>High</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>SUN38</td>
#       <td>2021-11-01</td>
#       <td>00:30:00</td>
#       <td>German Division 1 [GSL]</td>
#       <td>Monchengladbach</td>
#       <td>Bochum</td>
#       <td>False</td>
#       <td>10.5</td>
#       <td>2.30</td>
#       <td>1.54</td>
#       <td>0.284693</td>
#       <td>0.715307</td>
#       <td>0.188098</td>
#       <td>Low</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>FRI9</td>
#       <td>2021-10-30</td>
#       <td>02:30:00</td>
#       <td>German Division 1 [GSL]</td>
#       <td>Hoffenheim</td>
#       <td>Hertha Berlin</td>
#       <td>False</td>
#       <td>10.5</td>
#       <td>2.25</td>
#       <td>1.57</td>
#       <td>0.297802</td>
#       <td>0.702198</td>
#       <td>0.179738</td>
#       <td>Low</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>SAT35</td>
#       <td>2021-10-30</td>
#       <td>22:00:00</td>
#       <td>Eng Premier [EPL]</td>
#       <td>Watford</td>
#       <td>Southampton</td>
#       <t

# %%
odds.to_csv(path_output/f'odds-{datetime.now().strftime("%Y-%m-%d")}.csv', float_format='%.2f', index=False)

# %% [markdown]
# ## END
