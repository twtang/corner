# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.tabular.all import *
from wwf.tab.export import *
from bnb import *

from classes import *
from utils import *

# %%
SEASON = '21'
set_seed(int(SEASON))

# %% [markdown]
# ## Download HKJC odds

# %%
path_raw = Path('raw_data')
path_data = Path('data')

path_output = Path('output')

# %%
session = requests.Session()
r = session.get('http://bet.hkjc.com')
cookies = r.cookies

# %%
odds_url = 'https://bet.hkjc.com/football/getJSON.aspx?jsontype=odds_chl.aspx'
response = session.post(
    odds_url,
    headers={'referer':'http://bet.hkjc.com'},
    cookies=cookies
)

# %%
with open(path_data/'json'/f'odds_chl-{datetime.now().strftime("%Y-%m-%d-%H-%M-%S")}.txt', 'w') as f:
    f.write(response.text)

# %%
matches_json = json.loads(response.text)[1]['matches']

# %%
# Example
# matches_json = json.loads(open(path_data/'json'/'odds_chl-2021-09-21-14-03-17.txt').read())[1]['matches']

# %%
matches = [Match(m) for m in matches_json]
odds = [m.export() for m in matches]
# Out:
# ['20211210FRI2', '2021-Dec-10', '23:00:00', 'Cup Competition [CUP]', 'Tunisia', 'Oman', 'true', '9.5', '2.20', '1.59', 'false', '10.5', '2.70', '1.40', 'false', '12.5', '4.55', '1.15']
# ['20211210FRI3', '2021-Dec-11', '01:30:00', 'German Division 2 [GD2]', 'Schalke 04', 'Nurnberg', 'false', '13.5', '3.90', '1.20', 'true', '10.5', '1.92', '1.78', 'false', '11.5', '2.40', '1.50']
# ['20211210FRI4', '2021-Dec-11', '01:30:00', 'German Division 2 [GD2]', 'Jahn Regensburg', 'Werder Bremen', 'false', '13.5', '5.10', '1.12', 'false', '10.5', '2.20', '1.59', 'true', '9.5', '1.77', '1.93']
# ['20211210FRI16', '2021-Dec-11', '03:00:00', 'Cup Competition [CUP]', 'Qatar', 'United Arab Emirates', 'false', '9.5', '2.55', '1.45', 'true', '8.5', '1.95', '1.75', 'false', '11.5', '4.55', '1.15']
# ['20211210FRI17', '2021-Dec-11', '03:30:00', 'German Division 1 [GSL]', 'Cologne', 'Augsburg', 'false', '10.5', '2.45', '1.48', 'true', '9.5', '1.92', '1.78', 'false', '12.5', '4.15', '1.18']
# ['20211210FRI18', '2021-Dec-11', '03:45:00', 'Italian Division 1 [ISA]', 'Genoa', 'Sampdoria', 'false', '10.5', '2.30', '1.54', 'false', '13.5', '5.10', '1.12', 'true', '9.5', '1.85', '1.85']
# ['20211210FRI20', '2021-Dec-11', '04:00:00', 'Eng Premier [EPL]', 'Brentford', 'Watford', 'false', '12.5', '4.15', '1.18', 'false', '10.5', '2.30', '1.54', 'true', '9.5', '1.85', '1.85']
# ['20211210FRI21', '2021-Dec-11', '04:00:00', 'Spanish Division 1 [SFL]', 'Mallorca', 'Celta Vigo', 'true', '8.5', '1.92', '1.78', 'false', '12.5', '6.10', '1.08', 'false', '9.5', '2.50', '1.46']
# ['20211210FRI22', '2021-Dec-11', '04:00:00', 'French Division 1 [FFL]', 'Nantes', 'Lens', 'false', '13.5', '5.10', '1.12', 'true', '9.5', '1.82', '1.88', 'false', '10.5', '2.30', '1.54']
# ['20211211SAT2', '2021-Dec-11', '14:05:00', 'Australian Division 1 [AD1]', 'Western Utd', 'Brisbane Roar', 'false', '12.5', '2.45', '1.48', 'true', '11.5', '2.00', '1.72', 'false', '14.5', '4.05', '1.19']
# ['20211211SAT3', '2021-Dec-11', '16:45:00', 'Australian Division 1 [AD1]', 'Western Sydney Wanderers', 'Macarthur FC', 'false', '15.5', '4.55', '1.15', 'false', '12.5', '2.20', '1.59', 'true', '11.5', '1.82', '1.88']
# ['20211211SAT4', '2021-Dec-11', '16:45:00', 'Australian Division 1 [AD1]', 'Adelaide Utd', 'Melbourne Victory', 'true', '11.5', '1.88', '1.82', 'false', '12.5', '2.30', '1.54', 'false', '15.5', '4.75', '1.14']
# ['20211211SAT6', '2021-Dec-11', '19:00:00', 'Russian Premier [RPL]', 'Krylya Sovetov Samara', 'Rubin Kazan', 'true', '9.5', '1.88', '1.82', 'false', '10.5', '2.40', '1.50', 'false', '13.5', '4.90', '1.13']
# ['20211211SAT7', '2021-Dec-11', '20:30:00', 'Eng Premier [EPL]', 'Manchester City', 'Wolves', 'false', '14.5', '4.40', '1.16', 'true', '11.5', '2.13', '1.63', 'false', '12.5', '2.70', '1.40']
# ['20211211SAT8', '2021-Dec-11', '20:30:00', 'Eng Championship [ED1]', 'Huddersfield', 'Coventry', 'false', '10.5', '2.33', '1.53', 'true', '9.5', '1.83', '1.87', 'false', '13.5', '5.30', '1.11']
# ['20211211SAT9', '2021-Dec-11', '20:30:00', 'German Division 2 [GD2]', 'Holstein Kiel', 'Sandhausen', 'false', '11.5', '2.50', '1.46', 'false', '13.5', '4.15', '1.18', 'true', '10.5', '2.00', '1.72']
# ['20211211SAT10', '2021-Dec-11', '20:30:00', 'German Division 2 [GD2]', 'Ingolstadt', 'Hannover', 'true', '9.5', '1.80', '1.90', 'false', '10.5', '2.25', '1.57', 'false', '13.5', '5.10', '1.12']
# ['20211211SAT11', '2021-Dec-11', '20:30:00', 'German Division 2 [GD2]', 'Paderborn', 'Darmstadt', 'false', '10.5', '2.15', '1.62', 'true', '9.5', '1.75', '1.95', 'false', '13.5', '4.75', '1.14']
# ['20211211SAT12', '2021-Dec-11', '21:00:00', 'Spanish Division 1 [SFL]', 'Espanyol', 'Levante', 'false', '14.5', '7.00', '1.06', 'false', '10.5', '2.35', '1.52', 'true', '9.5', '1.85', '1.85']
# ['20211211SAT15', '2021-Dec-11', '21:30:00', 'Russian Premier [RPL]', 'CSKA Moscow', 'Arsenal Tula', 'false', '11.5', '2.83', '1.37', 'true', '10.5', '2.19', '1.60', 'false', '13.5', '4.55', '1.15']
# ['20211211SAT16', '2021-Dec-11', '22:00:00', 'Italian Division 1 [ISA]', 'Fiorentina', 'Salernitana', 'false', '10.5', '2.15', '1.62', 'false', '13.5', '4.55', '1.15', 'true', '9.5', '1.73', '1.98']
# ['20211211SAT19', '2021-Dec-11', '22:30:00', 'German Division 1 [GSL]', 'Bayern Munich', 'Mainz', 'true', '10.5', '1.98', '1.73', 'false', '14.5', '4.90', '1.13', 'false', '11.5', '2.50', '1.46']
# ['20211211SAT20', '2021-Dec-11', '22:30:00', 'German Division 1 [GSL]', 'Bochum', 'Dortmund', 'false', '12.5', '4.15', '1.18', 'true', '9.5', '1.95', '1.75', 'false', '10.5', '2.50', '1.46']
# ['20211211SAT21', '2021-Dec-11', '22:30:00', 'German Division 1 [GSL]', 'Freiburg', 'Hoffenheim', 'false', '12.5', '4.15', '1.18', 'false', '10.5', '2.45', '1.48', 'true', '9.5', '1.92', '1.78']
# ['20211211SAT22', '2021-Dec-11', '22:30:00', 'German Division 1 [GSL]', 'Hertha Berlin', 'Bielefeld', 'false', '10.5', '2.50', '1.46', 'false', '12.5', '4.15', '1.18', 'true', '9.5', '1.95', '1.75']
# ['20211211SAT23', '2021-Dec-11', '22:30:00', 'German Division 1 [GSL]', 'RB Leipzig', 'Monchengladbach', 'false', '10.5', '2.30', '1.54', 'true', '9.5', '1.83', '1.87', 'false', '13.5', '4.90', '1.13']
# ['20211211SAT24', '2021-Dec-11', '23:00:00', 'Eng Premier [EPL]', 'Liverpool', 'Aston Villa', 'true', '11.5', '2.02', '1.70', 'false', '14.5', '4.05', '1.19', 'false', '12.5', '2.55', '1.45']
# ['20211211SAT25', '2021-Dec-11', '23:00:00', 'Eng Premier [EPL]', 'Chelsea', 'Leeds', 'false', '14.5', '4.55', '1.15', 'false', '12.5', '2.80', '1.38', 'true', '11.5', '2.19', '1.60']
# ['20211211SAT26', '2021-Dec-11', '23:00:00', 'Eng Premier [EPL]', 'Arsenal', 'Southampton', 'false', '14.5', '5.10', '1.12', 'false', '11.5', '2.38', '1.51', 'true', '10.5', '1.88', '1.82']
# ['20211211SAT54', '2021-Dec-11', '23:15:00', 'Spanish Division 1 [SFL]', 'Alaves', 'Getafe', 'false', '9.5', '2.50', '1.46', 'false', '12.5', '6.10', '1.08', 'true', '8.5', '1.92', '1.78']
# ['20211211SAT57', '2021-Dec-12', '00:00:00', 'French Division 1 [FFL]', 'Brest', 'Montpellier', 'false', '10.5', '2.50', '1.46', 'true', '9.5', '1.93', '1.77', 'false', '12.5', '4.15', '1.18']
# ['20211211SAT60', '2021-Dec-12', '01:00:00', 'Italian Division 1 [ISA]', 'Venezia', 'Juventus', 'true', '9.5', '1.82', '1.88', 'false', '13.5', '4.90', '1.13', 'false', '10.5', '2.30', '1.54']
# ['20211211SAT62', '2021-Dec-12', '01:30:00', 'Eng Premier [EPL]', 'Norwich', 'Manchester Utd', 'false', '14.5', '4.75', '1.14', 'false', '11.5', '2.25', '1.57', 'true', '10.5', '1.80', '1.90']
# ['20211211SAT63', '2021-Dec-12', '01:30:00', 'Spanish Division 1 [SFL]', 'Valencia', 'CF Elche', 'true', '8.5', '1.90', '1.80', 'false', '9.5', '2.48', '1.47', 'false', '12.5', '5.80', '1.09']
# ['20211211SAT64', '2021-Dec-12', '01:30:00', 'German Division 1 [GSL]', 'Wolfsburg', 'Stuttgart', 'true', '9.5', '1.78', '1.92', 'false', '10.5', '2.25', '1.57', 'false', '13.5', '4.75', '1.14']
# ['20211211SAT81', '2021-Dec-12', '03:30:00', 'German Division 2 [GD2]', 'Dusseldorf', 'St. Pauli', 'false', '13.5', '4.30', '1.17', 'true', '10.5', '2.05', '1.68', 'false', '11.5', '2.55', '1.45']
# ['20211211SAT83', '2021-Dec-12', '03:45:00', 'Italian Division 1 [ISA]', 'Udinese', 'AC Milan', 'false', '10.5', '2.33', '1.53', 'true', '9.5', '1.83', '1.87', 'false', '13.5', '5.10', '1.12']
# ['20211211SAT85', '2021-Dec-12', '04:00:00', 'Spanish Division 1 [SFL]', 'Bilbao', 'Sevilla', 'false', '13.5', '7.00', '1.06', 'true', '8.5', '1.77', '1.93', 'false', '9.5', '2.27', '1.56']
# ['20211211SAT86', '2021-Dec-12', '04:00:00', 'French Division 1 [FFL]', 'Reims', 'St. Etienne', 'false', '13.5', '5.10', '1.12', 'false', '10.5', '2.25', '1.57', 'true', '9.5', '1.80', '1.90']
# ['20211211SAT93', '2021-Dec-12', '04:00:00', 'US Football League [MLS]', 'Portland Timbers', 'New York City', 'false', '11.5', '2.80', '1.38', 'true', '10.5', '2.15', '1.62', 'false', '13.5', '4.55', '1.15']
# ['20211212SUN1', '2021-Dec-12', '13:00:00', "Emperor's Cup [JEC]", 'Kawasaki Frontale', 'Oita Trinita', 'false', '12.5', '4.40', '1.16', 'false', '10.5', '2.60', '1.43', 'true', '9.5', '2.00', '1.72']
# ['20211212SUN2', '2021-Dec-12', '13:00:00', 'Korean Division 1 [KD1]', 'Gangwon FC', 'Daejeon Citizen', 'false', '12.5', '4.05', '1.19', 'true', '9.5', '1.93', '1.77', 'false', '10.5', '2.45', '1.48']
# ['20211212SUN3', '2021-Dec-12', '15:00:00', "Emperor's Cup [JEC]", 'Urawa Reds', 'Cerezo Osaka', 'true', '9.5', '2.02', '1.70', 'false', '12.5', '4.40', '1.16', 'false', '10.5', '2.65', '1.42']
# ['20211212SUN4', '2021-Dec-12', '15:15:00', 'Australian Division 1 [AD1]', 'Central Coast Mariners', 'Sydney FC', 'false', '14.5', '4.30', '1.17', 'true', '11.5', '2.15', '1.62', 'false', '12.5', '2.70', '1.40']
# ['20211212SUN5', '2021-Dec-12', '19:00:00', 'Russian Premier [RPL]', 'Dinamo Moscow', 'Zenit St. Petersburg', 'false', '12.5', '4.30', '1.17', 'false', '10.5', '2.60', '1.43', 'true', '9.5', '2.00', '1.72']
# ['20211212SUN7', '2021-Dec-12', '19:30:00', 'Italian Division 1 [ISA]', 'AC Torino', 'Bologna', 'true', '9.5', '1.82', '1.88', 'false', '13.5', '4.90', '1.13', 'false', '10.5', '2.30', '1.54']
# ['20211212SUN8', '2021-Dec-12', '20:00:00', 'French Division 1 [FFL]', 'Lille', 'Lyon', 'true', '9.5', '1.90', '1.80', 'false', '13.5', '5.55', '1.10', 'false', '10.5', '2.40', '1.50']
# ['20211212SUN11', '2021-Dec-12', '20:30:00', 'German Division 2 [GD2]', 'Aue', 'Dresden', 'true', '9.5', '1.93', '1.77', 'false', '13.5', '5.55', '1.10', 'false', '10.5', '2.45', '1.48']
# ['20211212SUN12', '2021-Dec-12', '20:30:00', 'German Division 2 [GD2]', 'Hamburg', 'Rostock', 'true', '10.5', '1.90', '1.80', 'false', '14.5', '5.10', '1.12', 'false', '11.5', '2.35', '1.52']
# ['20211212SUN13', '2021-Dec-12', '20:30:00', 'German Division 2 [GD2]', 'Karlsruher', 'Heidenheim', 'true', '10.5', '2.05', '1.68', 'false', '14.5', '5.80', '1.09', 'false', '11.5', '2.55', '1.45']
# ['20211212SUN15', '2021-Dec-12', '21:00:00', 'Spanish Division 1 [SFL]', 'Villarreal', 'Vallecano', 'false', '13.5', '7.00', '1.06', 'true', '8.5', '1.75', '1.95', 'false', '9.5', '2.25', '1.57']
# ['20211212SUN20', '2021-Dec-12', '21:30:00', 'Russian Premier [RPL]', 'Akhmat Grozny', 'Khimki', 'false', '10.5', '2.75', '1.39', 'true', '9.5', '2.10', '1.65', 'false', '12.5', '4.55', '1.15']
# ['20211212SUN21', '2021-Dec-12', '22:00:00', 'Eng Premier [EPL]', 'Leicester', 'Newcastle', 'true', '10.5', '1.92', '1.78', 'false', '11.5', '2.43', '1.49', 'false', '14.5', '5.30', '1.11']
# ['20211212SUN22', '2021-Dec-12', '22:00:00', 'Eng Premier [EPL]', 'Burnley', 'West Ham', 'false', '11.5', '2.43', '1.49', 'true', '10.5', '1.92', '1.78', 'false', '14.5', '5.30', '1.11']
# ['20211212SUN24', '2021-Dec-12', '22:00:00', 'Italian Division 1 [ISA]', 'Verona', 'Atalanta', 'false', '12.5', '4.15', '1.18', 'true', '9.5', '1.93', '1.77', 'false', '10.5', '2.50', '1.46']
# ['20211212SUN25', '2021-Dec-12', '22:00:00', 'French Division 1 [FFL]', 'Rennes', 'Nice', 'false', '10.5', '2.20', '1.59', 'true', '9.5', '1.75', '1.95', 'false', '13.5', '4.90', '1.13']
# ['20211212SUN26', '2021-Dec-12', '22:00:00', 'French Division 1 [FFL]', 'Angers SCO', 'Clermont', 'false', '12.5', '4.15', '1.18', 'true', '9.5', '1.95', '1.75', 'false', '10.5', '2.50', '1.46']
# ['20211212SUN27', '2021-Dec-12', '22:00:00', 'French Division 1 [FFL]', 'Metz', 'Lorient', 'true', '9.5', '1.87', '1.83', 'false', '10.5', '2.35', '1.52', 'false', '13.5', '5.30', '1.11']
# ['20211212SUN28', '2021-Dec-12', '22:00:00', 'French Division 1 [FFL]', 'Troyes', 'Bordeaux', 'false', '12.5', '4.15', '1.18', 'false', '10.5', '2.50', '1.46', 'true', '9.5', '1.93', '1.77']
# ['20211212SUN29', '2021-Dec-12', '22:30:00', 'German Division 1 [GSL]', 'Greuther Furth', 'Union Berlin', 'false', '12.5', '4.55', '1.15', 'true', '9.5', '2.10', '1.65', 'false', '10.5', '2.70', '1.40']
# ['20211212SUN32', '2021-Dec-12', '23:15:00', 'Spanish Division 1 [SFL]', 'Osasuna', 'Barcelona', 'false', '9.5', '2.27', '1.56', 'true', '8.5', '1.77', '1.93', 'false', '13.5', '7.00', '1.06']
# ['20211212SUN36', '2021-Dec-13', '00:00:00', 'French Division 1 [FFL]', 'Strasbourg', 'Marseille', 'true', '9.5', '1.78', '1.92', 'false', '13.5', '4.75', '1.14', 'false', '10.5', '2.20', '1.59']
# ['20211212SUN37', '2021-Dec-13', '00:00:00', 'Russian Premier [RPL]', 'FK Krasnodar', 'FC Nizhny Novgorod', 'false', '12.5', '4.05', '1.19', 'false', '10.5', '2.50', '1.46', 'true', '9.5', '1.93', '1.77']
# ['20211212SUN38', '2021-Dec-13', '00:00:00', 'Russian Premier [RPL]', 'Lokomotiv Moscow', 'Ufa', 'true', '10.5', '2.07', '1.67', 'false', '11.5', '2.65', '1.42', 'false', '13.5', '4.30', '1.17']
# ['20211212SUN49', '2021-Dec-13', '00:30:00', 'Eng Premier [EPL]', 'Crystal Palace', 'Everton', 'false', '11.5', '2.83', '1.37', 'false', '13.5', '4.75', '1.14', 'true', '10.5', '2.19', '1.60']
# ['20211212SUN50', '2021-Dec-13', '00:30:00', 'German Division 1 [GSL]', 'Frankfurt', 'Leverkusen', 'true', '10.5', '2.13', '1.63', 'false', '13.5', '4.55', '1.15', 'false', '11.5', '2.70', '1.40']
# ['20211212SUN51', '2021-Dec-13', '01:00:00', 'Italian Division 1 [ISA]', 'Napoli', 'Empoli', 'false', '10.5', '2.30', '1.54', 'true', '9.5', '1.83', '1.87', 'false', '13.5', '4.90', '1.13']
# ['20211212SUN52', '2021-Dec-13', '01:00:00', 'Italian Division 1 [ISA]', 'Sassuolo', 'Lazio', 'false', '10.5', '2.45', '1.48', 'true', '9.5', '1.92', '1.78', 'false', '12.5', '4.05', '1.19']
# ['20211212SUN54', '2021-Dec-13', '01:30:00', 'Spanish Division 1 [SFL]', 'Betis', 'Real Sociedad', 'false', '13.5', '7.00', '1.06', 'true', '8.5', '1.78', '1.92', 'false', '9.5', '2.29', '1.55']
# ['20211212SUN60', '2021-Dec-13', '03:45:00', 'Italian Division 1 [ISA]', 'Inter Milan', 'Cagliari', 'false', '13.5', '4.30', '1.17', 'true', '10.5', '2.07', '1.67', 'false', '11.5', '2.65', '1.42']
# ['20211212SUN61', '2021-Dec-13', '03:45:00', 'French Division 1 [FFL]', 'Paris Saint Germain', 'Monaco', 'false', '13.5', '5.55', '1.10', 'true', '9.5', '1.95', '1.75', 'false', '10.5', '2.45', '1.48']
# ['20211212SUN62', '2021-Dec-13', '04:00:00', 'Spanish Division 1 [SFL]', 'Real Madrid', 'Atletico Madrid', 'false', '13.5', '5.80', '1.09', 'false', '10.5', '2.65', '1.42', 'true', '9.5', '2.02', '1.70']
# ['20211212SUN69', '2021-Dec-13', '10:15:00', 'Mexican Premier [MXL]', 'Atlas', 'Club Leon', 'false', '12.5', '4.90', '1.13', 'true', '9.5', '2.13', '1.63', 'false', '10.5', '2.70', '1.40']
# ['20211213MON3', '2021-Dec-14', '00:00:00', 'Russian Premier [RPL]', 'PFC Sochi', 'Spartak Moscow', 'false', '10.5', '2.25', '1.57', 'true', '9.5', '1.80', '1.90', 'false', '13.5', '4.75', '1.14']
# ['20211213MON8', '2021-Dec-14', '03:45:00', 'Italian Division 1 [ISA]', 'Roma', 'Spezia', 'false', '13.5', '4.90', '1.13', 'false', '10.5', '2.30', '1.54', 'true', '9.5', '1.83', '1.87']
# ['20211213MON11', '2021-Dec-14', '04:00:00', 'Spanish Division 1 [SFL]', 'Cadiz', 'CF Granada', 'false', '13.5', '7.00', '1.06', 'true', '8.5', '1.73', '1.98', 'false', '9.5', '2.20', '1.59']

# %%
cols_match = ['MatchDay', 'Date', 'Time', 'LeagueJC', 'HomeTeamJC', 'AwayTeamJC']
cols_odds0 = ['MAINLINE_0', 'CHL_LINE_0', 'CHL_H_0', 'CHL_L_0']
cols_odds1 = ['MAINLINE_1', 'CHL_LINE_1', 'CHL_H_1', 'CHL_L_1']
cols_odds2 = ['MAINLINE_2', 'CHL_LINE_2', 'CHL_H_2', 'CHL_L_2']
cols_odds  = ['MAINLINE', 'CHL_LINE', 'CHL_H', 'CHL_L']
cols_pred  = ['prob_0', 'prob_1', 'prob_2', 'total_count']

cols = cols_match + cols_odds0 + cols_odds1 + cols_odds2

# %%
odds = pd.DataFrame(odds, columns=cols)
odds = odds.fillna(value=np.nan)

# %%
cols_odds_ = cols_odds0[1:]+cols_odds1[1:]+cols_odds2[1:]
odds[cols_odds_] = odds[cols_odds_].astype(float)

# %%
odds['MatchDay'] = odds['MatchDay'].str[8:]
odds['Date'] = pd.to_datetime(odds['Date'])
odds['Time'] = pd.to_datetime(odds['Time'], format='%H:%M:%S').dt.time

# %%
odds['DateTimeJC'] = pd.to_datetime(odds['Date'].dt.date.map(str) + '-' + odds['Time'].map(str))
odds['DateTimeJC'] = odds['DateTimeJC'].dt.tz_localize('Hongkong')
odds['DateTime'] = odds['DateTimeJC'].dt.tz_convert('GB')

# %%
map_league = pd.read_csv(path_data/'league.csv')
map_team = pd.read_csv(path_data/'team.csv')

# %%
div = ['E0', 'D1', 'SP1', 'I1', 'F1']
map_league = map_league[map_league.Div.isin(div)].reset_index(drop=True)

# %%
# Map Div name
odds = odds.merge(map_league[['LeagueJC', 'Div']], 'inner', on='LeagueJC')

# %%
# Map Team name
odds = odds.merge(map_team[['TeamNameJC', 'TeamName']].rename(columns={'TeamName':'HomeTeam'}), 'inner', 
                  left_on='HomeTeamJC', right_on='TeamNameJC').drop(columns=['TeamNameJC'])
odds = odds.merge(map_team[['TeamNameJC', 'TeamName']].rename(columns={'TeamName':'AwayTeam'}), 'inner', 
                  left_on='AwayTeamJC', right_on='TeamNameJC').drop(columns=['TeamNameJC'])

# %% [markdown]
# ## Download recent stats

# %%
# Download latest results in current season
# !wget -q https://www.football-data.co.uk/mmz4281/{SEASON}{int(SEASON)+1}/data.zip -O raw_data/data.zip

# Unzip to folder
# !unzip -q -o raw_data/data.zip -d raw_data/{SEASON}

# %%
usecols = ['Div', 'Date', 'HomeTeam', 'AwayTeam', 'HC', 'AC', 'FTHG', 'FTAG', 'HS', 'AS', 'HST', 'AST']
dtype = {'HC':'float', 'AC':'float'}
parse_dates = ['Date']

seasons = [SEASON]

dfs = []

for folder in sorted(path_raw.iterdir()):
    if folder.is_dir() and folder.name in seasons: 
        for file in sorted(folder.glob('*.csv')):
            try:
                df = pd.read_csv(file, usecols=usecols, dtype=dtype, parse_dates=parse_dates, dayfirst=True)
                df['Season'] = folder.name
                dfs.append(df)
            except:
                continue

# %%
df_season = pd.concat(dfs)
df_season = df_season.dropna()
df_season = df_season.sort_values(['Div', 'Date', 'HomeTeam']).reset_index(drop=True)

# %%
df_hist = pd.read_csv(path_data/'data.csv', dtype={'HC':'float', 'AC':'float'}, parse_dates=['Date'])
df_hist = df_hist.query(f'Season == {int(SEASON)-1}').reset_index(drop=True)

# %%
df_season = pd.concat([df_hist[df_season.columns], df_season])

# %%
# Make features on historical stats (Home and Away)
stats = ['FTHG', 'HS', 'HST', 'HC', 'FTAG', 'AS', 'AST', 'AC']
df_home, df_away = joinLastGamesStatsHomeAway(df_season, stats)

# %%
# Make features on historical stats (For and Against)
stats = [('FTHG', 'FTAG', 'FTG'), ('HS', 'AS', 'S'), ('HST', 'AST', 'ST'), ('HC', 'AC', 'C')]
df_for, df_against = joinLastGamesStatsForAgainst(df_season, stats)

# %%
df_home = df_home.sort_values(['HomeTeam', 'Date']).reset_index(drop=True)
df_away = df_away.sort_values(['AwayTeam', 'Date']).reset_index(drop=True)

df_home = df_home.groupby('HomeTeam')[df_home.columns[df_home.columns.str.contains('Avg')]].last().reset_index()
df_away = df_away.groupby('AwayTeam')[df_away.columns[df_away.columns.str.contains('Avg')]].last().reset_index()

# %%
odds = odds.merge(df_home, 'left', 'HomeTeam').merge(df_away, 'left', 'AwayTeam')

# %%
cols_home = df_for.columns[df_for.columns.str.contains('Avg')]
cols_home = dict(zip(cols_home, 'Home'+cols_home))
cols_home.update({'Team':'HomeTeam'})

cols_away = df_for.columns[df_for.columns.str.contains('Avg')]
cols_away = dict(zip(cols_home, 'Away'+cols_away))
cols_away.update({'Team':'AwayTeam'})

df_for = df_for.groupby('Team')[df_for.columns[df_for.columns.str.contains('Avg')]].last().reset_index()
odds = odds.merge(df_for.rename(columns=cols_home), 'left', 'HomeTeam').merge(df_for.rename(columns=cols_away), 'left', 'AwayTeam')

# %%
cols_home = df_against.columns[df_against.columns.str.contains('Avg')]
cols_home = dict(zip(cols_home, 'Home'+cols_home))
cols_home.update({'Team':'HomeTeam'})

cols_away = df_against.columns[df_against.columns.str.contains('Avg')]
cols_away = dict(zip(cols_home, 'Away'+cols_away))
cols_away.update({'Team':'AwayTeam'})

df_against = df_against.groupby('Team')[df_against.columns[df_against.columns.str.contains('Avg')]].last().reset_index()
odds = odds.merge(df_against.rename(columns=cols_home), 'left', 'HomeTeam').merge(df_against.rename(columns=cols_away), 'left', 'AwayTeam')

# %%
add_datepart(odds, 'DateTime', prefix='', drop=False);

# %%
display_df(odds.head(5).T)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>MatchDay</th>
#       <td>FRI17</td>
#       <td>SAT19</td>
#       <td>SAT20</td>
#       <td>SAT21</td>
#       <td>SAT22</td>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <td>2021-12-11 00:00:00</td>
#       <td>2021-12-11 00:00:00</td>
#       <td>2021-12-11 00:00:00</td>
#       <td>2021-12-11 00:00:00</td>
#       <td>2021-12-11 00:00:00</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>03:30:00</td>
#       <td>22:30:00</td>
#       <td>22:30:00</td>
#       <td>22:30:00</td>
#       <td>22:30:00</td>
#     </tr>
#     <tr>
#       <th>LeagueJC</th>
#       <td>German Division 1 [GSL]</td>
#       <td>German Division 1 [GSL]</td>
#       <td>German Division 1 [GSL]</td>
#       <td>German Division 1 [GSL]</td>
#       <td>German Division 1 [GSL]</td>
#     </tr>
#     <tr>
#       <th>HomeTeamJC</th>
#       <td>Cologne</td>
#       <td>Bayern Munich</td>
#       <td>Bochum</td>
#       <td>Freiburg</td>
#       <td>Hertha Berlin</td>
#     </tr>
#     <tr>
#       <th>AwayTeamJC</th>
#       <td>Augsburg</td>
#       <td>Mainz</td>
#       <td>Dortmund</td>
#       <td>Hoffenheim</td>
#       <td>Bielefeld</td>
#     </tr>
#     <tr>
#       <th>MAINLINE_0</th>
#       <td>false</td>
#       <td>true</td>
#       <td>false</td>
#       <td>false</td>
#       <td>false</td>
#     </tr>
#     <tr>
#       <th>CHL_LINE_0</th>
#       <td>10.5</td>
#       <td>10.5</td>
#       <td>12.5</td>
#       <td>12.5</td>
#       <td>10.5</td>
#     </tr>
#     <tr>
#       <th>CHL_H_0</th>
#       <td>2.45</td>
#       <td>1.98</td>
#       <td>4.15</td>
#       <td>4.15</td>
#       <td>2.5</td>
#     </tr>
#     <tr>
#       <th>CHL_L_0</th>
#       <td>1.48</td>
#       <td>1.73</td>
#       <td>1.18</td>
#       <td>1.18</td>
#       <td>1.46</td>
#     </tr>
#     <tr>
#       <th>MAINLINE_1</th>
#       <td>true</td>
#       <td>false</td>
#       <td>true</td>
#       <td>false</td>
#       <td>false</td>
#     </tr>
#     <tr>
#       <th>CHL_LINE_1</th>
#       <td>9.5</td>
#       <td>14.5</td>
#       <td>9.5</td>
#       <td>10.5</td>
#       <td>12.5</td>
#     </tr>
#     <tr>
#       <th>CHL_H_1</th>
#       <td>1.92</td>
#       <td>4.9</td>
#       <td>1.95</td>
#       <td>2.45</td>
#       <td>4.15</td>
#     </tr>
#     <tr>
#       <th>CHL_L_1</th>
#       <td>1.78</td>
#       <td>1.13</td>
#       <td>1.75</td>
#       <td>1.48</td>
#       <td>1.18</td>
#     </tr>
#     <tr>
#       <th>MAINLINE_2</th>
#       <td>false</td>
#       <td>false</td>
#       <td>false</td>
#       <td>true</td>
#       <td>true</td>
#     </tr>
#     <tr>
#       <th>CHL_LINE_2</th>
#       <td>12.5</td>
#       <td>11.5</td>
#       <td>10.5</td>
#       <td>9.5</td>
#       <td>9.5</td>
#     </tr>
#     <tr>
#       <th>CHL_H_2</th>
#       <td>4.15</td>
#       <td>2.5</td>
#       <td>2.5</td>
#       <td>1.92</td>
#       <td>1.95</td>
#     </tr>
#     <tr>
#       <th>CHL_L_2</th>
#       <td>1.18</td>
#       <td>1.46</td>
#       <td>1.46</td>
#       <td>1.78</td>
#       <td>1.75</td>
#     </tr>
#     <tr>
#       <th>DateTimeJC</th>
#       <td>2021-12-11 03:30:00+08:00</td>
#       <td>2021-12-11 22:30:00+08:00</td>
#       <td>2021-12-11 22:30:00+08:00</td>
#       <td>2021-12-11 22:30:00+08:00</td>
#       <td>2021-12-11 22:30:00+08:00</td>
#     </tr>
#     <tr>
#       <th>DateTime</th>
#       <td>2021-12-10 19:30:00+00:00</td>
#       <td>2021-12-11 14:30:00+00:00</td>
#       <td>2021-12-11 14:30:00+00:00</td>
#       <td>2021-12-11 14:30:00+00:00</td>
#       <td>2021-12-11 14:30:00+00:00</td>
#     </tr>
#     <tr>
#       <th>Div</th>
#       <td>D1</td>
#       <td>D1</td>
#       <td>D1</td>
#       <td>D1</td>
#       <td>D1</td>
#     </tr>
#     <tr>
#       <th>HomeTeam</th>
#       <td>FC Koln</td>
#       <td>Bayern Munich</td>
#       <td>Bochum</td>
#       <td>Freiburg</td>
#       <td>Hertha</td>
#     </tr>
#     <tr>
#       <th>AwayTeam</th>
#       <td>Augsburg</td>
#       <td>Mainz</td>
#       <td>Dortmund</td>
#       <td>Hoffenheim</td>
#       <td>Bielefeld</td>
#     </tr>
#     <tr>
#       <th>FTHGLast5Avg</th>
#       <td>2.0</td>
#       <td>3.8</td>
#       <td>1.4</td>
#       <td>2.0</td>
#       <td>1.2</td>
#     </tr>
#     <tr>
#       <th>HSLast5Avg</th>
#       <td>17.2</td>
#       <td>20.8</td>
#       <td>15.0</td>
#       <td>12.8</td>
#       <td>12.8</td>
#     </tr>
#     <tr>
#       <th>HSTLast5Avg</th>
#       <td>5.8</td>
#       <td>10.0</td>
#       <td>5.0</td>
#       <td>4.6</td>
#       <td>3.8</td>
#     </tr>
#     <tr>
#       <th>HCLast5Avg</th>
#       <td>5.6</td>
#       <td>6.0</td>
#       <td>4.4</td>
#       <td>4.6</td>
#       <td>4.8</td>
#     </tr>
#     <tr>
#       <th>FTAGLast5Avg</th>
#       <td>0.4</td>
#       <td>1.0</td>
#       <td>1.8</td>
#       <td>0.6</td>
#       <td>0.8</td>
#     </tr>
#     <tr>
#       <th>ASLast5Avg</th>
#       <td>9.0</td>
#       <td>12.4</td>
#       <td>13.0</td>
#       <td>11.2</td>
#       <td>12.2</td>
#     </tr>
#     <tr>
#       <th>ASTLast5Avg</th>
#       <td>3.2</td>
#       <td>4.0</td>
#       <td>3.8</td>
#       <td>3.0</td>
#       <td>3.2</td>
#     </tr>
#     <tr>
#       <th>ACLast5Avg</th>
#       <td>4.0</td>
#       <td>4.6</td>
#       <td>4.4</td>
#       <td>4.6</td>
#       <td>3.4</td>
#     </tr>
#     <tr>
#       <th>HomeFTGForLast5Avg</th>
#       <td>1.8</td>
td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>Week</th>
#       <td>49</td>
#       <td>49</td>
#       <td>49</td>
#       <td>49</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>Day</th>
#       <td>10</td>
#       <td>11</td>
#       <td>11</td>

# %% [markdown]
# ## Load model

# %%
learn_bnb = load_learner('models/learn_bnb.pkl')

# %%
to = load_pandas('models/to.pkl')

# %%
def predict(self, row):
    "Predict on a Pandas Series"
    dl = self.dls.test_dl(row.to_frame().T)
    dl.dataset.conts = dl.dataset.conts.astype(np.float32)
    inp,preds,_ = self.get_preds(dl=dl, with_input=True, with_decoded=False)
    b = tuplify(inp)
    full_dec = self.dls.decode(b)
    return full_dec,preds[0]

learn_bnb.predict = MethodType(predict, learn_bnb)

# %%
to_tst = to.new(odds)
to_tst.process()
# to_tst.items.head()

# %%
tst_dl = learn_bnb.dls.valid.new(to_tst)
tst_dl.show(max_n=999)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Div</th>
#       <th>HomeTeam</th>
#       <th>AwayTeam</th>
#       <th>FTHGLast5Avg</th>
#       <th>HSLast5Avg</th>
#       <th>HSTLast5Avg</th>
#       <th>HCLast5Avg</th>
#       <th>FTAGLast5Avg</th>
#       <th>ASLast5Avg</th>
#       <th>ASTLast5Avg</th>
#       <th>ACLast5Avg</th>
#       <th>HomeFTGForLast5Avg</th>
#       <th>HomeSForLast5Avg</th>
#       <th>HomeSTForLast5Avg</th>
#       <th>HomeCForLast5Avg</th>
#       <th>AwayFTGForLast5Avg</th>
#       <th>AwaySForLast5Avg</th>
#       <th>AwaySTForLast5Avg</th>
#       <th>AwayCForLast5Avg</th>
#       <th>HomeFTGAgainstLast5Avg</th>
#       <th>HomeSAgainstLast5Avg</th>
#       <th>HomeSTAgainstLast5Avg</th>
#       <th>HomeCAgainstLast5Avg</th>
#       <th>AwayFTGAgainstLast5Avg</th>
#       <th>AwaySAgainstLast5Avg</th>
#       <th>AwaySTAgainstLast5Avg</th>
#       <th>AwayCAgainstLast5Avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>D1</td>
#       <td>FC Koln</td>
#       <td>Augsburg</td>
#       <td>2.0</td>
#       <td>17.2</td>
#       <td>5.8</td>
#       <td>5.6</td>
#       <td>0.4</td>
#       <td>9.0</td>
#       <td>3.2</td>
#       <td>4.0</td>
#       <td>1.8</td>
#       <td>15.8</td>
#       <td>6.2</td>
#       <td>5.0</td>
#       <td>1.6</td>
#       <td>13.0</td>
#       <td>5.4</td>
#       <td>4.8</td>
#       <td>1.6</td>
#       <td>10.2</td>
#       <td>4.0</td>
#       <td>4.2</td>
#       <td>1.6</td>
#       <td>13.6</td>
#       <td>4.6</td>
#       <td>5.2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td
td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>I1</td>
#       <td>Venezia</td>
#       <td>Juventus</td>
#       <td>1.2</td>
#       <td>7.8</td>
#       <td>3.2</td>
#       <td>3.4</td>
#       <td>1.6</td>
#       <td>15.6</td>
#       <td>5.0</td>
#       <td>5.2</td>
#       <td>0.8</td>
#       <td>8.2</td>
#       <td>4.0</td>
#       <td>2.6</td>
#       <td>1.2</td>
#       <td>14.4</td>
#       <td>4.2</td>
#       <td>3.6</td>
#       <td>1.6</td>
#       <td>22.8</td>
#       <td>7.4</td>
#       <td>10.6</td>
#       <td>0.6</td>
#       <td>7.4</td>
#       <td>1.6</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>I1</td>
#       <td>Udinese</td>
#       <td>Milan</td>
#       <td>1.0</td>
#       <td>12.0</td>
#       <td>3.0</td>
#       <td>3.2</td>
#       <td>2.8</td>
#       <td>14.2</td>
#       <td>5.8</td>
#       <td>3.6</td>

# %%
pred, _ = learn_bnb.get_preds(dl=tst_dl)

# %%
probs = F.softmax(pred[:, :3], dim=-1)
total_count = 1 / F.softplus(pred[:, 3:])

# %%
odds[cols_pred] = torch.cat([probs, total_count], dim=-1)

# %%
odds0 = odds[cols_match+cols_odds0+cols_pred].rename(columns=dict(zip(cols_odds0, cols_odds)))
odds1 = odds[cols_match+cols_odds1+cols_pred].rename(columns=dict(zip(cols_odds1, cols_odds)))
odds2 = odds[cols_match+cols_odds2+cols_pred].rename(columns=dict(zip(cols_odds2, cols_odds)))

# %%
odds = pd.concat([odds0, odds1, odds2]).dropna().reset_index(drop=True)
odds['MAINLINE'] = np.where(odds['MAINLINE']=='true', True, False)

# %%
odds.head(10)
# Out:
#   MatchDay       Date      Time                  LeagueJC      HomeTeamJC  \
# 0    FRI17 2021-12-11  03:30:00   German Division 1 [GSL]         Cologne
# 1    SAT19 2021-12-11  22:30:00   German Division 1 [GSL]   Bayern Munich
# 2    SAT20 2021-12-11  22:30:00   German Division 1 [GSL]          Bochum
# 3    SAT21 2021-12-11  22:30:00   German Division 1 [GSL]        Freiburg
# 4    SAT22 2021-12-11  22:30:00   German Division 1 [GSL]   Hertha Berlin
# 5    SAT23 2021-12-11  22:30:00   German Division 1 [GSL]      RB Leipzig
# 6    SAT64 2021-12-12  01:30:00   German Division 1 [GSL]       Wolfsburg
# 7    SUN29 2021-12-12  22:30:00   German Division 1 [GSL]  Greuther Furth
# 8    SUN50 2021-12-13  00:30:00   German Division 1 [GSL]       Frankfurt
# 9    FRI18 2021-12-11  03:45:00  Italian Division 1 [ISA]           Genoa
#
#         AwayTeamJC  MAINLINE  CHL_LINE  CHL_H  CHL_L    prob_0    prob_1  \
# 0         Augsburg     False      10.5   2.45   1.48  0.799290  0.122709
# 1            Mainz      True      10.5   1.98   1.73  0.699720  0.234256
# 2         Dortmund     False      12.5   4.15   1.18  0.783931  0.100204
# 3       Hoffenheim     False      12.5   4.15   1.18  0.805192  0.100330
# 4        Bielefeld     False      10.5   2.50   1.46  0.811423  0.100699
# 5  Monchengladbach     False      10.5   2.30   1.54  0.807938  0.107894
# 6        Stuttgart      True       9.5   1.78   1.92  0.818674  0.093913
# 7     Union Berlin     False      12.5   4.55   1.15  0.818951  0.097001
# 8       Leverkusen      True      10.5   2.13   1.63  0.811428  0.110151
# 9        Sampdoria     False      10.5   2.30   1.54  0.810743  0.103862
#
#      prob_2  total_count
# 0  0.078001    35.255527
# 1  0.066024    27.718168
# 2  0.115865    32.857338
# 3  0.094478    42.177868
# 4  0.087878    39.179932
# 5  0.084169    38.495243
# 6  0.087412    41.856003
# 7  0.084048    39.761520
# 8  0.078421    45.499290
# 9  0.085395    43.209206

# %%
prob_hilo = []

for r in list(zip(odds['prob_0'], odds['prob_1'], odds['prob_2'], odds['total_count'], odds['CHL_LINE'])):
    probs = torch.tensor(r[0:3], device='cpu')
    total_count = torch.tensor(r[3], device='cpu')

    bnb_corner = BivariateNegativeBinomial(total_count=total_count, probs=probs)
    value = torch.cartesian_prod(torch.arange(0., 15.), torch.arange(0., 15.))
    corner = bnb_corner.log_prob(value).exp()
    
    line = r[4]
    mask = value.sum(-1) < line
    prob_lo = corner[mask].sum()
    prob_hi = 1 - prob_lo
    
    prob_hilo.append([prob_hi.item(), prob_lo.item()])

# %%
odds[['prob_hi', 'prob_lo']] = prob_hilo

# %%
odds['kelly_hi'] = (odds['prob_hi'] * odds['CHL_H'] - 1) / (odds['CHL_H'] - 1)
odds['kelly_lo'] = (odds['prob_lo'] * odds['CHL_L'] - 1) / (odds['CHL_L'] - 1)

# %%
odds['kelly'] = np.where(
    np.maximum(odds['kelly_hi'], odds['kelly_lo']) > 0, 
    np.where(odds['kelly_hi'] > odds['kelly_lo'], odds['kelly_hi'], odds['kelly_lo']), 
    np.nan
)

# %%
odds['bet'] = np.where(
    np.maximum(odds['kelly_hi'], odds['kelly_lo']) > 0, 
    np.where(odds['kelly_hi'] > odds['kelly_lo'], 'High', 'Low'), 
    None
)

# %%
odds = odds.sort_values('kelly', ascending=False).reset_index(drop=True)

# %%
odds['selected'] = np.where(
    odds['MAINLINE']==True, np.where(
        odds['kelly']>0.3, '$$$', np.where(
            odds['kelly']>0.2, '$$', np.where(
                odds['kelly']>0.1, '$', None))), 
    None
)

# %%
odds = odds.drop(columns=cols_pred+['kelly_hi', 'kelly_lo'])

# %%
odds[odds.bet.notna() & odds.selected.notna()]
# Out:
#    MatchDay       Date      Time                  LeagueJC  \
# 2     SUN36 2021-12-13  00:00:00   French Division 1 [FFL]
# 3     SAT16 2021-12-11  22:00:00  Italian Division 1 [ISA]
# 4     SAT26 2021-12-11  23:00:00         Eng Premier [EPL]
# 7     SUN61 2021-12-13  03:45:00   French Division 1 [FFL]
# 8     SAT19 2021-12-11  22:30:00   German Division 1 [GSL]
# 10    SUN62 2021-12-13  04:00:00  Spanish Division 1 [SFL]
# 13     SUN7 2021-12-12  19:30:00  Italian Division 1 [ISA]
# 14    SAT63 2021-12-12  01:30:00  Spanish Division 1 [SFL]
# 17    SAT12 2021-12-11  21:00:00  Spanish Division 1 [SFL]
# 19     MON8 2021-12-14  03:45:00  Italian Division 1 [ISA]
#
#              HomeTeamJC       AwayTeamJC  MAINLINE  CHL_LINE  CHL_H  CHL_L  \
# 2            Strasbourg        Marseille      True       9.5   1.78   1.92
# 3            Fiorentina      Salernitana      True       9.5   1.73   1.98
# 4               Arsenal      Southampton      True      10.5   1.88   1.82
# 7   Paris Saint Germain           Monaco      True       9.5   1.95   1.75
# 8         Bayern Munich            Mainz      True      10.5   1.98   1.73
# 10          Real Madrid  Atletico Madrid      True       9.5   2.02   1.70
# 13            AC Torino          Bologna      True       9.5   1.82   1.88
# 14             Valencia         CF Elche      True       8.5   1.90   1.80
# 17             Espanyol          Levante      True       9.5   1.85   1.85
# 19                 Roma           Spezia      True       9.5   1.83   1.87
#
#      prob_hi   prob_lo     kelly   bet selected
# 2   0.342660  0.657340  0.284883   Low       $$
# 3   0.693983  0.306017  0.274781  High       $$
# 4   0.659470  0.340530  0.272504  High       $$
# 7   0.619737  0.380263  0.219460  High       $$
# 8   0.606679  0.393321  0.205332  High       $$
# 10  0.585746  0.414254  0.179614  High        $
# 13  0.615826  0.384174  0.147322  High        $
# 14  0.596023  0.403977  0.147159  High        $
# 17  0.593211  0.406789  0.114636  High        $
# 19  0.595511  0.404489  0.108176  High        $

# %%
display_df(odds[odds.MatchDay.isin(odds[odds.bet.notna() & odds.selected.notna()].MatchDay) & odds.bet.notna()])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MatchDay</th>
#       <th>Date</th>
#       <th>Time</th>
#       <th>LeagueJC</th>
#       <th>HomeTeamJC</th>
#       <th>AwayTeamJC</th>
#       <th>MAINLINE</th>
#       <th>CHL_LINE</th>
#       <th>CHL_H</th>
#       <th>CHL_L</th>
#       <th>prob_hi</th>
#       <th>prob_lo</th>
#       <th>kelly</th>
#       <th>bet</th>
#       <th>selected</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>SUN36</td>
#       <td>2021-12-13</td>
#       <td>00:00:00</td>
#       <td>French Division 1 [FFL]</td>
#       <td>Strasbourg</td>
#       <td>Marseille</td>
#       <td>False</td>
#       <td>13.5</td>
#       <td>4.75</td>
#       <td>1.14</td>
#       <td>0.069637</td>
#       <td>0.930363</td>
#       <td>0.432955</td>
#       <td>Low</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>SUN36</td>
#       <td>2021-12-13</td>
#       <td>00:00:00</td>
#       <td>French Division 1 [FFL]</td>
#       <td>Strasbourg</td>
#       <td>Marseille</td>
#       <td>False</td>
#       <td>10.5</td>
#       <td>2.20</td>
#       <td>1.59</td>
#       <td>0.245425</td>
#       <td>0.754575</td>
#       <td>0.338601</td>
#       <td>Low</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>SUN36</td>
#       <td>2021-12-13</td>
#       <td>00:00:00</td>
#       <td>French Division 1 [FFL]</td>
#       <td>Strasbourg</td>
#       <td>Marseille</td>
#       <td>True</td>
#       <td>9.5</td>
#       <td>1.78</td>
#       <td>1.92</td>
#       <td>0.342660</td>
#       <td>0.657340</td>
#       <td>0.284883</td>
#       <td>Low</td>
#       <td>$$</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td