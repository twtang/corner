# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.tabular.all import *
from wwf.tab.export import *
from bnb import *

from classes import *
from utils import *

# %%
SEASON = '22'
set_seed(int(SEASON))

# %% [markdown]
# ## Download HKJC odds

# %%
path_raw = Path('raw_data')
path_data = Path('data')

path_output = Path('output')

# %%
session = requests.Session()
r = session.get('http://bet.hkjc.com')
cookies = r.cookies

# %%
odds_url = 'https://bet.hkjc.com/football/getJSON.aspx?jsontype=odds_chl.aspx'
response = session.post(
    odds_url,
    headers={'referer':'http://bet.hkjc.com'},
    cookies=cookies
)

# %%
with open(path_data/'json'/f'odds_chl-{datetime.now().strftime("%Y-%m-%d-%H-%M-%S")}.txt', 'w') as f:
    f.write(response.text)

# %%
matches_json = json.loads(response.text)[1]['matches']

# %%
# Example
# matches_json = json.loads(open(path_data/'json'/'odds_chl-2021-09-21-14-03-17.txt').read())[1]['matches']

# %%
matches = [Match(m) for m in matches_json]
odds = [m.export() for m in matches]
# Out:
# ['20220213SUN1', '2022-Feb-13', '14:45:00', 'Australian Division 1 [AD1]', 'Central Coast Mariners', 'Perth Glory', 'true', '14.5', '1.76', '1.94', 'false', '15.5', '2.22', '1.58']
# ['20220213SUN2', '2022-Feb-13', '15:45:00', 'Australian Division 1 [AD1]', 'Brisbane Roar', 'Macarthur FC', 'false', '11.5', '2.40', '1.50', 'true', '10.5', '1.90', '1.80', 'false', '14.5', '4.55', '1.15']
# ['20220213SUN5', '2022-Feb-13', '19:30:00', 'Italian Division 1 [ISA]', 'AC Milan', 'Sampdoria', 'true', '10.5', '2.00', '1.72', 'false', '14.5', '5.30', '1.11', 'false', '11.5', '2.50', '1.46']
# ['20220213SUN6', '2022-Feb-13', '20:00:00', 'French Division 1 [FFL]', 'Monaco', 'Lorient', 'true', '9.5', '1.90', '1.80', 'false', '10.5', '2.40', '1.50', 'false', '13.5', '5.30', '1.11']
# ['20220213SUN7', '2022-Feb-13', '20:00:00', 'Eng League 1 [ED2]', 'Sheff Wednesday', 'Rotherham', 'false', '11.5', '2.30', '1.54', 'true', '10.5', '1.85', '1.85', 'false', '14.5', '4.90', '1.13']
# ['20220213SUN9', '2022-Feb-13', '20:30:00', 'German Division 2 [GD2]', 'Dusseldorf', 'Schalke 04', 'false', '14.5', '5.55', '1.10', 'true', '10.5', '2.00', '1.72', 'false', '11.5', '2.50', '1.46']
# ['20220213SUN10', '2022-Feb-13', '20:30:00', 'German Division 2 [GD2]', 'Hannover', 'Darmstadt', 'false', '10.5', '2.20', '1.59', 'true', '9.5', '1.75', '1.95', 'false', '13.5', '4.75', '1.14']
# ['20220213SUN11', '2022-Feb-13', '20:30:00', 'German Division 2 [GD2]', 'Ingolstadt', 'Sandhausen', 'false', '13.5', '4.40', '1.16', 'true', '10.5', '2.10', '1.65', 'false', '11.5', '2.65', '1.42']
# ['20220213SUN13', '2022-Feb-13', '21:00:00', 'Spanish Division 1 [SFL]', 'Alaves', 'Valencia', 'false', '10.5', '2.70', '1.40', 'false', '12.5', '4.70', '1.14', 'true', '9.5', '2.10', '1.65']
# ['20220213SUN21', '2022-Feb-13', '22:00:00', 'Eng Premier [EPL]', 'Burnley', 'Liverpool', 'false', '14.5', '4.30', '1.17', 'true', '11.5', '2.10', '1.65', 'false', '12.5', '2.60', '1.43']
# ['20220213SUN22', '2022-Feb-13', '22:00:00', 'Eng Premier [EPL]', 'Tottenham', 'Wolves', 'true', '10.5', '1.90', '1.80', 'false', '11.5', '2.40', '1.50', 'false', '14.5', '5.10', '1.12']
# ['20220213SUN23', '2022-Feb-13', '22:00:00', 'Eng Premier [EPL]', 'Newcastle', 'Aston Villa', 'false', '13.5', '4.05', '1.19', 'true', '10.5', '1.95', '1.75', 'false', '11.5', '2.48', '1.47']
# ['20220213SUN24', '2022-Feb-13', '22:00:00', 'Italian Division 1 [ISA]', 'Verona', 'Udinese', 'false', '14.5', '5.80', '1.09', 'false', '11.5', '2.70', '1.40', 'true', '10.5', '2.10', '1.65']
# ['20220213SUN25', '2022-Feb-13', '22:00:00', 'Italian Division 1 [ISA]', 'Empoli', 'Cagliari', 'true', '9.5', '1.80', '1.90', 'false', '13.5', '4.90', '1.13', 'false', '10.5', '2.25', '1.57']
# ['20220213SUN26', '2022-Feb-13', '22:00:00', 'Italian Division 1 [ISA]', 'Genoa', 'Salernitana', 'false', '10.5', '2.30', '1.54', 'true', '9.5', '1.83', '1.87', 'false', '13.5', '5.10', '1.12']
# ['20220213SUN27', '2022-Feb-13', '22:00:00', 'French Division 1 [FFL]', 'Clermont', 'St. Etienne', 'true', '9.5', '1.90', '1.80', 'false', '13.5', '5.30', '1.11', 'false', '10.5', '2.40', '1.50']
# ['20220213SUN28', '2022-Feb-13', '22:00:00', 'French Division 1 [FFL]', 'Angers SCO', 'Strasbourg', 'false', '10.5', '2.55', '1.45', 'true', '9.5', '1.98', '1.73', 'false', '12.5', '4.25', '1.17']
# ['20220213SUN29', '2022-Feb-13', '22:00:00', 'French Division 1 [FFL]', 'Brest', 'Troyes', 'false', '10.5', '2.55', '1.45', 'true', '9.5', '1.98', '1.73', 'false', '12.5', '4.25', '1.17']
# ['20220213SUN30', '2022-Feb-13', '22:00:00', 'French Division 1 [FFL]', 'Nantes', 'Reims', 'false', '13.5', '5.30', '1.11', 'false', '10.5', '2.40', '1.50', 'true', '9.5', '1.90', '1.80']
# ['20220213SUN32', '2022-Feb-13', '22:30:00', 'German Division 1 [GSL]', 'Union Berlin', 'Dortmund', 'true', '9.5', '2.05', '1.68', 'false', '12.5', '4.40', '1.16', 'false', '10.5', '2.60', '1.43']
# ['20220213SUN35', '2022-Feb-13', '23:15:00', 'Spanish Division 1 [SFL]', 'Levante', 'Betis', 'false', '10.5', '2.70', '1.40', 'true', '9.5', '2.07', '1.67', 'false', '12.5', '4.55', '1.15']
# ['20220213SUN42', '2022-Feb-14', '00:05:00', 'French Division 1 [FFL]', 'Lens', 'Bordeaux', 'false', '10.5', '2.50', '1.46', 'true', '9.5', '1.95', '1.75', 'false', '12.5', '4.25', '1.17']
# ['20220213SUN43', '2022-Feb-14', '00:30:00', 'Eng Premier [EPL]', 'Leicester', 'West Ham', 'false', '14.5', '4.90', '1.13', 'false', '11.5', '2.33', '1.53', 'true', '10.5', '1.85', '1.85']
# ['20220213SUN44', '2022-Feb-14', '00:30:00', 'German Division 1 [GSL]', 'Hoffenheim', 'Bielefeld', 'false', '11.5', '2.65', '1.42', 'false', '13.5', '4.25', '1.17', 'true', '10.5', '2.10', '1.65']
# ['20220213SUN45', '2022-Feb-14', '01:00:00', 'Italian Division 1 [ISA]', 'Sassuolo', 'Roma', 'false', '11.5', '2.60', '1.43', 'false', '13.5', '4.15', '1.18', 'true', '10.5', '2.05', '1.68']
# ['20220213SUN48', '2022-Feb-14', '01:30:00', 'Spanish Division 1 [SFL]', 'Real Sociedad', 'CF Granada', 'false', '10.5', '2.88', '1.36', 'false', '12.5', '5.10', '1.12', 'true', '9.5', '2.20', '1.59']
# ['20220213SUN55', '2022-Feb-14', '03:45:00', 'Italian Division 1 [ISA]', 'Atalanta', 'Juventus', 'false', '13.5', '5.10', '1.12', 'false', '10.5', '2.35', '1.52', 'true', '9.5', '1.88', '1.82']
# ['20220213SUN56', '2022-Feb-14', '03:45:00', 'French Division 1 [FFL]', 'Metz', 'Marseille', 'false', '10.5', '2.20', '1.59', 'true', '9.5', '1.77', '1.93', 'false', '13.5', '4.75', '1.14']
# ['20220213SUN57', '2022-Feb-14', '04:00:00', 'Spanish Division 1 [SFL]', 'Espanyol', 'Barcelona', 'false', '12.5', '4.15', '1.18', 'false', '10.5', '2.50', '1.46', 'true', '9.5', '1.95', '1.75']
# ['20220213SUN67', '2022-Feb-14', '07:30:00', 'Brazilian Paulista League [BPC]', 'Sao Bernardo', 'RB Bragantino', 'false', '13.5', '4.40', '1.16', 'false', '11.5', '2.60', '1.43', 'true', '10.5', '2.02', '1.70']
# ['20220214MON8', '2022-Feb-15', '03:45:00', 'Italian Division 1 [ISA]', 'Spezia', 'Fiorentina', 'false', '12.5', '4.55', '1.15', 'false', '10.5', '2.70', '1.40', 'true', '9.5', '2.10', '1.65']
# ['20220214MON11', '2022-Feb-15', '04:00:00', 'Spanish Division 1 [SFL]', 'Mallorca', 'Bilbao', 'true', '9.5', '2.20', '1.59', 'false', '10.5', '2.90', '1.35', 'false', '12.5', '5.10', '1.12']
# ['20220214MON16', '2022-Feb-15', '07:30:00', 'Chilean Division 1 [CD1]', 'Cobresal', 'Curico Unido', 'false', '12.5', '4.90', '1.13', 'true', '9.5', '2.15', '1.62', 'false', '10.5', '2.83', '1.37']

# %%
cols_match = ['MatchDay', 'Date', 'Time', 'LeagueJC', 'HomeTeamJC', 'AwayTeamJC']
cols_odds0 = ['MAINLINE_0', 'CHL_LINE_0', 'CHL_H_0', 'CHL_L_0']
cols_odds1 = ['MAINLINE_1', 'CHL_LINE_1', 'CHL_H_1', 'CHL_L_1']
cols_odds2 = ['MAINLINE_2', 'CHL_LINE_2', 'CHL_H_2', 'CHL_L_2']
cols_odds  = ['MAINLINE', 'CHL_LINE', 'CHL_H', 'CHL_L']
cols_pred  = ['prob_0', 'prob_1', 'prob_2', 'total_count']

cols = cols_match + cols_odds0 + cols_odds1 + cols_odds2

# %%
odds = pd.DataFrame(odds, columns=cols)
odds = odds.fillna(value=np.nan)

# %%
cols_odds_ = cols_odds0[1:]+cols_odds1[1:]+cols_odds2[1:]
odds[cols_odds_] = odds[cols_odds_].astype(float)

# %%
odds['MatchDay'] = odds['MatchDay'].str[8:]
odds['Date'] = pd.to_datetime(odds['Date'])
odds['Time'] = pd.to_datetime(odds['Time'], format='%H:%M:%S').dt.time

# %%
odds['DateTimeJC'] = pd.to_datetime(odds['Date'].dt.date.map(str) + '-' + odds['Time'].map(str))
odds['DateTimeJC'] = odds['DateTimeJC'].dt.tz_localize('Hongkong')
odds['DateTime'] = odds['DateTimeJC'].dt.tz_convert('GB')

# %%
map_league = pd.read_csv(path_data/'league.csv')
map_team = pd.read_csv(path_data/'team.csv')

# %%
div = ['E0', 'D1', 'SP1', 'I1', 'F1']
map_league = map_league[map_league.Div.isin(div)].reset_index(drop=True)

# %%
# Map Div name
odds = odds.merge(map_league[['LeagueJC', 'Div']], 'inner', on='LeagueJC')

# %%
# Map Team name
odds = odds.merge(map_team[['TeamNameJC', 'TeamName']].rename(columns={'TeamName':'HomeTeam'}), 'inner', 
                  left_on='HomeTeamJC', right_on='TeamNameJC').drop(columns=['TeamNameJC'])
odds = odds.merge(map_team[['TeamNameJC', 'TeamName']].rename(columns={'TeamName':'AwayTeam'}), 'inner', 
                  left_on='AwayTeamJC', right_on='TeamNameJC').drop(columns=['TeamNameJC'])

# %% [markdown]
# ## Download recent stats

# %%
# Download latest results in current season
# !wget -q https://www.football-data.co.uk/mmz4281/{SEASON}{int(SEASON)+1}/data.zip -O raw_data/data.zip

# Unzip to folder
# !unzip -q -o raw_data/data.zip -d raw_data/{SEASON}

# %%
usecols = ['Div', 'Date', 'HomeTeam', 'AwayTeam', 'HC', 'AC', 'FTHG', 'FTAG', 'HS', 'AS', 'HST', 'AST']
dtype = {'HC':'float', 'AC':'float'}
parse_dates = ['Date']

seasons = [SEASON]

dfs = []

for folder in sorted(path_raw.iterdir()):
    if folder.is_dir() and folder.name in seasons: 
        for file in sorted(folder.glob('*.csv')):
            try:
                df = pd.read_csv(file, usecols=usecols, dtype=dtype, parse_dates=parse_dates, dayfirst=True)
                df['Season'] = folder.name
                dfs.append(df)
            except:
                continue

# %%
df_season = pd.concat(dfs)
df_season = df_season.dropna()
df_season = df_season.sort_values(['Div', 'Date', 'HomeTeam']).reset_index(drop=True)

# %%
df_hist = pd.read_csv(path_data/'data.csv', dtype={'HC':'float', 'AC':'float'}, parse_dates=['Date'])
df_hist = df_hist.query(f'Season == {int(SEASON)-1}').reset_index(drop=True)

# %%
df_season = pd.concat([df_hist[df_season.columns], df_season])

# %%
# Make features on historical stats (Home and Away)
stats = ['FTHG', 'HS', 'HST', 'HC', 'FTAG', 'AS', 'AST', 'AC']
df_home, df_away = joinLastGamesStatsHomeAway(df_season, stats)

# %%
# Make features on historical stats (For and Against)
stats = [('FTHG', 'FTAG', 'FTG'), ('HS', 'AS', 'S'), ('HST', 'AST', 'ST'), ('HC', 'AC', 'C')]
df_for, df_against = joinLastGamesStatsForAgainst(df_season, stats)

# %%
df_home = df_home.sort_values(['HomeTeam', 'Date']).reset_index(drop=True)
df_away = df_away.sort_values(['AwayTeam', 'Date']).reset_index(drop=True)

df_home = df_home.groupby('HomeTeam')[df_home.columns[df_home.columns.str.contains('Avg')]].last().reset_index()
df_away = df_away.groupby('AwayTeam')[df_away.columns[df_away.columns.str.contains('Avg')]].last().reset_index()

# %%
odds = odds.merge(df_home, 'left', 'HomeTeam').merge(df_away, 'left', 'AwayTeam')

# %%
cols_home = df_for.columns[df_for.columns.str.contains('Avg')]
cols_home = dict(zip(cols_home, 'Home'+cols_home))
cols_home.update({'Team':'HomeTeam'})

cols_away = df_for.columns[df_for.columns.str.contains('Avg')]
cols_away = dict(zip(cols_home, 'Away'+cols_away))
cols_away.update({'Team':'AwayTeam'})

df_for = df_for.groupby('Team')[df_for.columns[df_for.columns.str.contains('Avg')]].last().reset_index()
odds = odds.merge(df_for.rename(columns=cols_home), 'left', 'HomeTeam').merge(df_for.rename(columns=cols_away), 'left', 'AwayTeam')

# %%
cols_home = df_against.columns[df_against.columns.str.contains('Avg')]
cols_home = dict(zip(cols_home, 'Home'+cols_home))
cols_home.update({'Team':'HomeTeam'})

cols_away = df_against.columns[df_against.columns.str.contains('Avg')]
cols_away = dict(zip(cols_home, 'Away'+cols_away))
cols_away.update({'Team':'AwayTeam'})

df_against = df_against.groupby('Team')[df_against.columns[df_against.columns.str.contains('Avg')]].last().reset_index()
odds = odds.merge(df_against.rename(columns=cols_home), 'left', 'HomeTeam').merge(df_against.rename(columns=cols_away), 'left', 'AwayTeam')

# %%
add_datepart(odds, 'DateTime', prefix='', drop=False);

# %%
display_df(odds.head(5).T)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>MatchDay</th>
#       <td>SUN5</td>
#       <td>SUN24</td>
#       <td>SUN25</td>
#       <td>SUN26</td>
#       <td>SUN45</td>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <td>2022-02-13 00:00:00</td>
#       <td>2022-02-13 00:00:00</td>
#       <td>2022-02-13 00:00:00</td>
#       <td>2022-02-13 00:00:00</td>
#       <td>2022-02-14 00:00:00</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>19:30:00</td>
#       <td>22:00:00</td>
#       <td>22:00:00</td>
#       <td>22:00:00</td>
#       <td>01:00:00</td>
#     </tr>
#     <tr>
#       <th>LeagueJC</th>
#       <td>Italian Division 1 [ISA]</td>
#       <td>Italian Division 1 [ISA]</td>
#       <td>Italian Division 1 [ISA]</td>
#       <td>Italian Division 1 [ISA]</td>
#       <td>Italian Division 1 [ISA]</td>
#     </tr>
#     <tr>
#       <th>HomeTeamJC</th>
#       <td>AC Milan</td>
#       <td>Verona</td>
#       <td>Empoli</td>
#       <td>Genoa</td>
#       <td>Sassuolo</td>
#     </tr>
#     <tr>
#       <th>AwayTeamJC</th>
#       <td>Sampdoria</td>
#       <td>Udinese</td>
#       <td>Cagliari</td>
#       <td>Salernitana</td>
#       <td>Roma</td>
#     </tr>
#     <tr>
#       <th>MAINLINE_0</th>
#       <td>true</td>
#       <td>false</td>
#       <td>true</td>
#       <td>false</td>
#       <td>false</td>
#     </tr>
#     <tr>
#       <th>CHL_LINE_0</th>
#       <td>10.5</td>
#       <td>14.5</td>
#       <td>9.5</td>
#       <td>10.5</td>
#       <td>11.5</td>
#     </tr>
#     <tr>
#       <th>CHL_H_0</th>
#       <td>2.0</td>
#       <td>5.8</td>
#       <td>1.8</td>
#       <td>2.3</td>
#       <td>2.6</td>
#     </tr>
#     <tr>
#       <th>CHL_L_0</th>
#       <td>1.72</td>
#       <td>1.09</td>
#       <td>1.9</td>
#       <td>1.54</td>
#       <td>1.43</td>
#     </tr>
#     <tr>
#       <th>MAINLINE_1</th>
#       <td>false</td>
#       <td>false</td>
#       <td>false</td>
#       <td>true</td>
#       <td>false</td>
#     </tr>
#     <tr>
#       <th>CHL_LINE_1</th>
#       <td>14.5</td>
#       <td>11.5</td>
#       <td>13.5</td>
#       <td>9.5</td>
#       <td>13.5</td>
#     </tr>
#     <tr>
#       <th>CHL_H_1</th>
#       <td>5.3</td>
#       <td>2.7</td>
#       <td>4.9</td>
#       <td>1.83</td>
#       <td>4.15</td>
#     </tr>
#     <tr>
#       <th>CHL_L_1</th>
#       <td>1.11</td>
#       <td>1.4</td>
#       <td>1.13</td>
#       <td>1.87</td>
#       <td>1.18</td>
#     </tr>
#     <tr>
#       <th>MAINLINE_2</th>
#       <td>false</td>
#       <td>true</td>
#       <td>false</td>
#       <td>false</td>
#       <td>true</td>
#     </tr>
#     <tr>
#       <th>CHL_LINE_2</th>
#       <td>11.5</td>
#       <td>10.5</td>
#       <td>10.5</td>
#       <td>13.5</td>
#       <td>10.5</td>
#     </tr>
#     <tr>
#       <th>CHL_H_2</th>
#       <td>2.5</td>
#       <td>2.1</td>
#       <td>2.25</td>
#       <td>5.1</td>
#       <td>2.05</td>
#     </tr>
#     <tr>
#       <th>CHL_L_2</th>
#       <td>1.46</td>
#       <td>1.65</td>
#       <td>1.57</td>
#       <td>1.12</td>
#       <td>1.68</td>
#     </tr>
#     <tr>
#       <th>DateTimeJC</th>
#       <td>2022-02-13 19:30:00+08:00</td>
#       <td>2022-02-13 22:00:00+08:00</td>
#       <td>2022-02-13 22:00:00+08:00</td>
#       <td>2022-02-13 22:00:00+08:00</td>
#       <td>2022-02-14 01:00:00+08:00</td>
#     </tr>
#     <tr>
#       <th>DateTime</th>
#       <td>2022-02-13 11:30:00+00:00</td>
#       <td>2022-02-13 14:00:00+00:00</td>
#       <td>2022-02-13 14:00:00+00:00</td>
#       <td>2022-02-13 14:00:00+00:00</td>
#       <td>2022-02-13 17:00:00+00:00</td>
#     </tr>
#     <tr>
#       <th>Div</th>
#       <td>I1</td>
#       <td>I1</td>
#       <td>I1</td>
#       <td>I1</td>
#       <td>I1</td>
#     </tr>
#     <tr>
#       <th>HomeTeam</th>
#       <td>Milan</td>
#       <td>Verona</td>
#       <td>Empoli</td>
#       <td>Genoa</td>
#       <td>Sassuolo</td>
#     </tr>
#     <tr>
#       <th>AwayTeam</th>
#       <td>Sampdoria</td>
#       <td>Udinese</td>
#       <td>Cagliari</td>
#       <td>Salernitana</td>
#       <td>Roma</td>
#     </tr>
#     <tr>
#       <th>FTHGLast5Avg</th>
#       <td>1.4</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>0.2</td>
#       <td>1.4</td>
#     </tr>
#     <tr>
#       <th>HSLast5Avg</th>
#       <td>18.6</td>
#       <td>17.4</td>
#       <td>16.0</td>
#       <td>7.8</td>
#       <td>17.4</td>
#     </tr>
#     <tr>
#       <th>HSTLast5Avg</th>
#       <td>5.0</td>
#       <td>4.8</td>
#       <td>5.0</td>
#       <td>1.6</td>
#       <td>5.8</td>
#     </tr>
#     <tr>
#       <th>HCLast5Avg</th>
#       <td>6.8</td>
#       <td>7.6</td>
#       <td>6.4</td>
#       <td>4.2</td>
#       <td>5.8</td>
#     </tr>
#     <tr>
#       <th>FTAGLast5Avg</th>
#       <td>1.4</td>
#       <td>2.0</td>
#       <td>0.4</td>
#       <td>0.6</td>
#       <td>1.8</td>
#     </tr>
#     <tr>
#       <th>ASLast5Avg</th>
#       <td>11.6</td>
#       <td>15.0</td>
#       <td>9.2</td>
#       <td>8.0</td>
#       <td>15.6</td>
#     </tr>
#     <tr>
#       <th>ASTLast5Avg</th>
#       <td>3.8</td>
#       <td>5.6</td>
#       <td>3.2</td>
#       <td>3.0</td>
#       <td>5.8</td>
#     </tr>
#     <tr>
#       <th>ACLast5Avg</th>
#       <td>2.8</td>
#       <td>5.0</td>
#       <td>1.6</td>
#       <td>3.8</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>HomeFTGForLast5Avg</th>
#       <td>2.2</td>
#       <td>2.0</td>
#       <td>1.8</td>
#       <td>0.2</td>
#       <td>1.8</td>
#     </tr>
#     <tr>
#       <th>HomeSForLast5Avg</th>
#       <td>18.8</td>
#       <td>17.6</td>
#       <td>15.0</td>
#       <td>6.6</td>
#       <td>17.0</td>
#     </tr>
#     <tr>
#       <th>HomeSTForLast5Avg</th>
#       <td>6.6</td>
#       <td>5.2</td>
#       <td>5.2</td>
#       <td>1.2</td>
#       <td>6.4</td>
#     </tr>
#     <tr>
#       <th>HomeCForLast5Avg</th>
#       <td>5.4</td>
#       <td>8.2</td>
#       <td>4.2</td>
#       <td>4.8</td>
#       <td>5.8</td>
#     </tr>
#     <tr>
#       <th>AwayFTGForLast5Avg</th>
#       <td>0.6</td>
#       <td>1.4</td>
#       <td>1.0</td>
#       <td>0.6</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>AwaySForLast5Avg</th>
#       <td>8.6</td>
#       <td>9.4</td>
#       <td>10.8</td>
#       <td>7.4</td>
#       <td>15.2</td>
#     </tr>
#     <tr>
#       <th>AwaySTForLast5Avg</th>
#       <td>1.4</td>
#       <td>3.6</td>
#       <td>3.4</td>
#       <td>3.0</td>
#       <td>6.2</td>
#     </tr>
#     <tr>
#       <th>AwayCForLast5Avg</th>
#       <td>1.8</td>
#       <td>3.4</td>
#       <td>3.6</td>
#       <td>2.6</td>
#       <td>6.2</td>
#     </tr>
#     <tr>
#       <th>HomeFTGAgainstLast5Avg</th>
#       <td>1.0</td>
#       <td>1.4</td>
#       <td>3.4</td>
#       <td>1.6</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>HomeSAgainstLast5Avg</th>
#       <td>10.8</td>
#       <td>10.0</td>
#       <td>19.2</td>
#       <td>17.2</td>
#       <td>14.0</td>
#     </tr>
#     <tr>
#       <th>HomeSTAgainstLast5Avg</th>
#       <td>3.8</td>
#       <td>3.2</td>
#       <td>8.6</td>
#       <td>6.2</td>
#       <td>4.4</td>
#     </tr>
#     <tr>
#       <th>HomeCAgainstLast5Avg</th>
#       <td>3.8</td>
#       <td>5.8</td>
#       <td>5.2</td>
#       <td>5.4</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>AwayFTGAgainstLast5Avg</th>
#       <td>1.4</td>
#       <td>1.8</td>
#       <td>1.2</td>
#       <td>3.4</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>AwaySAgainstLast5Avg</th>
#       <td>15.8</td>
#       <td>12.4</td>
#       <td>11.8</td>
#       <td>21.0</td>
#       <td>13.4</td>
#     </tr>
#     <tr>
#       <th>AwaySTAgainstLast5Avg</th>
#       <td>6.0</td>
#       <td>3.4</td>
#       <td>4.2</td>
#       <td>9.2</td>
#       <td>4.2</td>
#     </tr>
#     <tr>
#       <th>AwayCAgainstLast5Avg</th>
#       <td>8.0</td>
#       <td>6.2</td>
#       <td>3.4</td>
#       <td>9.0</td>
#       <td>1.8</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>2022</td>
#       <td>2022</td>
#       <td>2022</td>
#       <td>2022</td>
#       <td>2022</td>
#     </tr>
#     <tr>
#       <th>Month</th>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Week</th>
#       <td>6</td>
#       <td>6</td>
#       <td>6</td>
#       <td>6</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Day</th>
#       <td>13</td>
#       <td>13</td>
#       <td>13</td>
#       <td>13</td>
#       <td>13</td>
#     </t

# %% [markdown]
# ## Load model

# %%
learn_bnb = load_learner('models/learn_bnb.pkl')

# %%
to = load_pandas('models/to.pkl')

# %%
def predict(self, row):
    "Predict on a Pandas Series"
    dl = self.dls.test_dl(row.to_frame().T)
    dl.dataset.conts = dl.dataset.conts.astype(np.float32)
    inp,preds,_ = self.get_preds(dl=dl, with_input=True, with_decoded=False)
    b = tuplify(inp)
    full_dec = self.dls.decode(b)
    return full_dec,preds[0]

learn_bnb.predict = MethodType(predict, learn_bnb)

# %%
to_tst = to.new(odds)
to_tst.process()
# to_tst.items.head()

# %%
tst_dl = learn_bnb.dls.valid.new(to_tst)
tst_dl.show(max_n=999)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Div</th>
#       <th>HomeTeam</th>
#       <th>AwayTeam</th>
#       <th>FTHGLast5Avg</th>
#       <th>HSLast5Avg</th>
#       <th>HSTLast5Avg</th>
#       <th>HCLast5Avg</th>
#       <th>FTAGLast5Avg</th>
#       <th>ASLast5Avg</th>
#       <th>ASTLast5Avg</th>
#       <th>ACLast5Avg</th>
#       <th>HomeFTGForLast5Avg</th>
#       <th>HomeSForLast5Avg</th>
#       <th>HomeSTForLast5Avg</th>
#       <th>HomeCForLast5Avg</th>
#       <th>AwayFTGForLast5Avg</th>
#       <th>AwaySForLast5Avg</th>
#       <th>AwaySTForLast5Avg</th>
#       <th>AwayCForLast5Avg</th>
#       <th>HomeFTGAgainstLast5Avg</th>
#       <th>HomeSAgainstLast5Avg</th>
#       <th>HomeSTAgainstLast5Avg</th>
#       <th>HomeCAgainstLast5Avg</th>
#       <th>AwayFTGAgainstLast5Avg</th>
#       <th>AwaySAgainstLast5Avg</th>
#       <th>AwaySTAgainstLast5Avg</th>
#       <th>AwayCAgainstLast5Avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td
td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>F1</td>
#       <td>Brest</td>
#       <td>Troyes</td>
#       <td>1.4</td>
#       <td>14.2</td>
#       <td>5.4</td>
#       <td>6.0</td>
#       <td>0.8</td>
#       <td>9.2</td>
#       <td>4.0</td>
#       <td>3.2</td>
#       <td>0.6</td>
#       <td>13.2</td>
#       <td>4.8</td>
#       <td>6.6</td>
#       <td>0.8</td>
#       <td>13.2</td>
#       <td>4.0</td>
#       <td>5.6</td>
#       <td>2.0</td>
#       <td>14.0</td>
#       <td>5.2</td>
#       <td>6.6</td>
#       <td>1.2</td>
#       <td>11.2</td>
#       <td>3.8</td>
#       <td>3.2</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>F1</td>
#       <td>Nantes</td>
#       <td>Reims</td>
#       <td>1.4</td>
#       <td>10.8</td>
#       <td>4.0</td>
#       <td>5.4</td>
#       <td>1.2</td>
#       <td>8.8</td>
#       <td>3.8</td>
#       <td>3.2</td>
#       <td>1.8</td>
#       <td>10.8</td>
#       <td>4.6</td>
#       <td>5.8</td>
#       <td>0.6</td>
#       <td>10.4</td>
#       <td>3.0</td>
#       <td>5.6</td>
#       <td>1.2</td>
#       <td>10.8</td>
#       <td>4.0</td>
#       <td>3.6</td>
#       <td>1.2</td>
#       <td>13.8</td>
#       <td>5.0</td>
#       <td>7.2</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>F1</td>
#       <td>Lens</td>
#       <td>Bordeaux</td>
#       <td>2.4</td>
#       <td>15.4</td>
#       <td>6.4</td>
#       <td>6.8</td>
#       <td>1.6</td>
#       <td>11.2</td>
#       <td>3.4</td>
#       <td>2.4</td>
#       <td>1.2</td>
#       <td>9.2</td>
#       <td>3.4</td>

# %%
pred, _ = learn_bnb.get_preds(dl=tst_dl)

# %%
probs = F.softmax(pred[:, :3], dim=-1)
total_count = 1 / F.softplus(pred[:, 3:])

# %%
odds[cols_pred] = torch.cat([probs, total_count], dim=-1)

# %%
odds0 = odds[cols_match+cols_odds0+cols_pred].rename(columns=dict(zip(cols_odds0, cols_odds)))
odds1 = odds[cols_match+cols_odds1+cols_pred].rename(columns=dict(zip(cols_odds1, cols_odds)))
odds2 = odds[cols_match+cols_odds2+cols_pred].rename(columns=dict(zip(cols_odds2, cols_odds)))

# %%
odds = pd.concat([odds0, odds1, odds2]).dropna().reset_index(drop=True)
odds['MAINLINE'] = np.where(odds['MAINLINE']=='true', True, False)

# %%
odds.head(10)
# Out:
#   MatchDay       Date      Time                  LeagueJC  HomeTeamJC  \
# 0     SUN5 2022-02-13  19:30:00  Italian Division 1 [ISA]    AC Milan
# 1    SUN24 2022-02-13  22:00:00  Italian Division 1 [ISA]      Verona
# 2    SUN25 2022-02-13  22:00:00  Italian Division 1 [ISA]      Empoli
# 3    SUN26 2022-02-13  22:00:00  Italian Division 1 [ISA]       Genoa
# 4    SUN45 2022-02-14  01:00:00  Italian Division 1 [ISA]    Sassuolo
# 5    SUN55 2022-02-14  03:45:00  Italian Division 1 [ISA]    Atalanta
# 6     MON8 2022-02-15  03:45:00  Italian Division 1 [ISA]      Spezia
# 7     SUN6 2022-02-13  20:00:00   French Division 1 [FFL]      Monaco
# 8    SUN27 2022-02-13  22:00:00   French Division 1 [FFL]    Clermont
# 9    SUN28 2022-02-13  22:00:00   French Division 1 [FFL]  Angers SCO
#
#     AwayTeamJC  MAINLINE  CHL_LINE  CHL_H  CHL_L    prob_0    prob_1  \
# 0    Sampdoria      True      10.5   2.00   1.72  0.841879  0.097874
# 1      Udinese     False      14.5   5.80   1.09  0.816663  0.107582
# 2     Cagliari      True       9.5   1.80   1.90  0.811614  0.106871
# 3  Salernitana     False      10.5   2.30   1.54  0.814481  0.114824
# 4         Roma     False      11.5   2.60   1.43  0.820584  0.076629
# 5     Juventus     False      13.5   5.10   1.12  0.790586  0.127494
# 6   Fiorentina     False      12.5   4.55   1.15  0.773642  0.079393
# 7      Lorient      True       9.5   1.90   1.80  0.817027  0.099560
# 8  St. Etienne      True       9.5   1.90   1.80  0.796928  0.115523
# 9   Strasbourg     False      10.5   2.55   1.45  0.804246  0.105031
#
#      prob_2  total_count
# 0  0.060247    63.769421
# 1  0.075754    43.525993
# 2  0.081515    43.559822
# 3  0.070696    43.280457
# 4  0.102788    52.110069
# 5  0.081920    33.306583
# 6  0.146965    30.771444
# 7  0.083413    46.204102
# 8  0.087549    34.365765
# 9  0.090723    37.186325

# %%
prob_hilo = []

for r in list(zip(odds['prob_0'], odds['prob_1'], odds['prob_2'], odds['total_count'], odds['CHL_LINE'])):
    probs = torch.tensor(r[0:3], device='cpu')
    total_count = torch.tensor(r[3], device='cpu')

    bnb_corner = BivariateNegativeBinomial(total_count=total_count, probs=probs)
    value = torch.cartesian_prod(torch.arange(0., 15.), torch.arange(0., 15.))
    corner = bnb_corner.log_prob(value).exp()
    
    line = r[4]
    mask = value.sum(-1) < line
    prob_lo = corner[mask].sum()
    prob_hi = 1 - prob_lo
    
    prob_hilo.append([prob_hi.item(), prob_lo.item()])
# Out:
# /Users/twtang/miniconda3/envs/fastai2/lib/python3.8/site-packages/torch/functional.py:1069: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /Users/distiller/project/conda/conda-bld/pytorch_1634272482218/work/aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.cartesian_prod(tensors)  # type: ignore[attr-defined]

# %%
odds[['prob_hi', 'prob_lo']] = prob_hilo

# %%
odds['kelly_hi'] = (odds['prob_hi'] * odds['CHL_H'] - 1) / (odds['CHL_H'] - 1)
odds['kelly_lo'] = (odds['prob_lo'] * odds['CHL_L'] - 1) / (odds['CHL_L'] - 1)

# %%
odds['kelly'] = np.where(
    np.maximum(odds['kelly_hi'], odds['kelly_lo']) > 0, 
    np.where(odds['kelly_hi'] > odds['kelly_lo'], odds['kelly_hi'], odds['kelly_lo']), 
    np.nan
)

# %%
odds['bet'] = np.where(
    np.maximum(odds['kelly_hi'], odds['kelly_lo']) > 0, 
    np.where(odds['kelly_hi'] > odds['kelly_lo'], 'High', 'Low'), 
    None
)

# %%
odds = odds.sort_values('kelly', ascending=False).reset_index(drop=True)

# %%
odds['selected'] = np.where(
    odds['MAINLINE']==True, np.where(
        odds['kelly']>0.3, '$$$', np.where(
            odds['kelly']>0.2, '$$', np.where(
                odds['kelly']>0.1, '$', None))), 
    None
)

# %%
odds = odds.drop(columns=cols_pred+['kelly_hi', 'kelly_lo'])

# %%
odds[odds.bet.notna() & odds.selected.notna()]
# Out:
#    MatchDay       Date      Time                  LeagueJC  HomeTeamJC  \
# 0      SUN5 2022-02-13  19:30:00  Italian Division 1 [ISA]    AC Milan
# 2     SUN29 2022-02-13  22:00:00   French Division 1 [FFL]       Brest
# 7     SUN44 2022-02-14  00:30:00   German Division 1 [GSL]  Hoffenheim
# 8     SUN45 2022-02-14  01:00:00  Italian Division 1 [ISA]    Sassuolo
# 9     SUN35 2022-02-13  23:15:00  Spanish Division 1 [SFL]     Levante
# 15    SUN27 2022-02-13  22:00:00   French Division 1 [FFL]    Clermont
# 17    SUN55 2022-02-14  03:45:00  Italian Division 1 [ISA]    Atalanta
# 18    SUN21 2022-02-13  22:00:00         Eng Premier [EPL]     Burnley
#
#      AwayTeamJC  MAINLINE  CHL_LINE  CHL_H  CHL_L   prob_hi   prob_lo  \
# 0     Sampdoria      True      10.5   2.00   1.72  0.632713  0.367287
# 2        Troyes      True       9.5   1.98   1.73  0.611613  0.388387
# 7     Bielefeld      True      10.5   2.10   1.65  0.328967  0.671033
# 8          Roma      True      10.5   2.05   1.68  0.570673  0.429327
# 9         Betis      True       9.5   2.07   1.67  0.566559  0.433441
# 15  St. Etienne      True       9.5   1.90   1.80  0.383456  0.616544
# 17     Juventus      True       9.5   1.88   1.82  0.391177  0.608823
# 18    Liverpool      True      11.5   2.10   1.65  0.343291  0.656709
#
#        kelly   bet selected
# 0   0.265426  High       $$
# 2   0.215299  High       $$
# 7   0.164930   Low        $
# 8   0.161791  High        $
# 9   0.161475  High        $
# 15  0.137225   Low        $
# 17  0.131777   Low        $
# 18  0.128568   Low        $

# %%
display_df(odds[odds.MatchDay.isin(odds[odds.bet.notna() & odds.selected.notna()].MatchDay) & odds.bet.notna()])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MatchDay</th>
#       <th>Date</th>
#       <th>Time</th>
#       <th>LeagueJC</th>
#       <th>HomeTeamJC</th>
#       <th>AwayTeamJC</th>
#       <th>MAINLINE</th>
#       <th>CHL_LINE</th>
#       <th>CHL_H</th>
#       <th>CHL_L</th>
#       <th>prob_hi</th>
#       <th>prob_lo</th>
#       <th>kelly</th>
#       <th>bet</th>
#       <th>selected</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>SUN5</td>
#       <td>2022-02-13</td>
#       <td>19:30:00</td>
#       <td>Italian Division 1 [ISA]</td>
#       <td>AC Milan</td>
#       <td>Sampdoria</td>
#       <td>True</td>
#       <td>10.5</td>
#       <td>2.00</td>
#       <td>1.72</td>
#       <td>0.632713</td>
#       <td>0.367287</td>
#       <td>0.265426</td>
#       <td>High</td>
#       <td>$$</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>SUN44</td>
#       <td>2022-02-14</td>
#       <td>00:30:00</td>
#       <td>German Division 1 [GSL]</td>
#       <td>Hoffenheim</td>
#       <td>Bielefeld</td>
#       <td>False</td>
#       <td>13.5</td>
#       <td>4.25</td>
#       <td>1.17</td>
#       <td>0.108636</td>
#       <td>0.891364</td>
#       <td>0.252328</td>
#       <td>Low</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>SUN29</td>
#       <td>2022-02-13</td>
#       <td>22:00:00</td>
#       <td>French Division 1 [FFL]</td>
#       <td>Brest</td>
#       <td>Troyes</td>
#       <td>True</td>
#       <td>9.5</td>
#       <td>1.98</td>
#       <td>1.73</td>
#       <td>0.611613</td>
#       <td>0.388387</td>
#       <td>0.215299</td>
#       <td>High</td>
#       <td>$$</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td